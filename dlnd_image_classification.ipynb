# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    xmax,xmin = x.max(),x.min()
    xnorm=(x-xmin)/(xmax-xmin)
    
    return xnorm


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
   
    for i in x:
        vec=np.zeros(10)
        np.put(vec,i,1)
        vec=np.array(vec,ndmin=2)
        try :
            vecs=np.concatenate((vecs,vec),axis=0)
        except :
            vecs=vec
    
    return vecs


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a bach of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    
    inputlayer= tf.placeholder(tf.float32, [None, image_shape[0],image_shape[1],image_shape[2]],name='x')
    return inputlayer


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    
    outputlayer=tf.placeholder(tf.float32, [None, n_classes],name='y')
    return outputlayer


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    prob=tf.placeholder(tf.float32, name='keep_prob')
    return prob


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()

tests.test_nn_image_inputs(neural_net_image_input)

tests.test_nn_label_inputs(neural_net_label_input)

tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    shape = x_tensor.get_shape().as_list() 
    weight_shape=[conv_ksize[0],conv_ksize[1],shape[3],conv_num_outputs]
    initial = tf.truncated_normal(weight_shape, stddev=0.1)
    weight=tf.Variable(initial)
    
    bias=tf.Variable(tf.zeros(shape=conv_num_outputs))
    conv=tf.nn.conv2d(x_tensor,  weight,[1,conv_strides[0],conv_strides[1],1],padding='SAME')
    
    conv=tf.add(conv,bias)
    conv=tf.nn.relu(conv)
    conv_pool=tf.nn.max_pool( conv,[1,pool_ksize[0],pool_ksize[1],1], [1,pool_strides[0],pool_strides[1],1],padding='SAME')
    
    return conv_pool 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
   
    shape = x_tensor.get_shape().as_list()  
    
    dim = np.prod(shape[1:])  
    flat=tf.reshape(x_tensor, [-1, dim])   
    return flat


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    shape = x_tensor.get_shape().as_list()     
    weight_shape=[shape[1],num_outputs]
    initial = tf.truncated_normal(weight_shape, stddev=0.1)
    weight=tf.Variable(initial)
    
    
#     weight = tf.Variable(tf.random_normal([shape[1],num_outputs]))  
    bias=tf.Variable(tf.zeros([num_outputs]))
    fcl=tf.add(tf.matmul(x_tensor,weight),bias)
    fcl=tf.nn.relu(fcl)
    return fcl


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    shape = x_tensor.get_shape().as_list()     
#     weight = tf.Variable(tf.random_normal([shape[1],num_outputs]))  
    weight_shape=[shape[1],num_outputs]
    initial = tf.truncated_normal(weight_shape, stddev=0.1)
    weight=tf.Variable(initial)
    
    
    bias=tf.Variable(tf.zeros([num_outputs]))
    mul=tf.matmul(x_tensor,weight)
    outputlayer=tf.add(tf.matmul(x_tensor,weight),bias)
    return outputlayer
    


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
#     nn=conv2d_maxpool(x, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    nn=conv2d_maxpool(x, 12, [3,3], [1,2,2,1], [3,3], [1,2,2,1],)
    nn=tf.nn.dropout(nn,keep_prob)
    nn=conv2d_maxpool(nn, 16, [3,3], [1,2,2,1], [3,3], [1,2,2,1],)
    nn=tf.nn.dropout(nn,keep_prob)
    nn=conv2d_maxpool(nn, 22, [3,3], [1,2,2,1], [3,3], [1,2,2,1],)
    nn=tf.nn.dropout(nn,keep_prob)
    
    

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    nn=flatten(nn)
    

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    nn=fully_conn(nn, 200)
    
    ##dropout
    nn=tf.nn.dropout(nn,keep_prob)
    
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    nn=output(nn, 10)
    
    
    # TODO: return output
    return nn


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    
    session.run( optimizer,feed_dict={x:feature_batch,y:label_batch, keep_prob: keep_probability })
    


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    global  valid_features 
    global valid_labels
    cost_score=session.run( cost,feed_dict={x:feature_batch,y:label_batch,keep_prob: 1.0 })
    accuracy_score=session.run( accuracy,feed_dict={x:valid_features,y:valid_labels ,keep_prob: 1.0})
    print(' cost_score',cost_score,'accuracy_score',accuracy_score )

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 500
batch_size = 8192
keep_probability = 0.8

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:   cost_score 2.299 accuracy_score 0.1212
# Epoch  2, CIFAR-10 Batch 1:   cost_score 2.29447 accuracy_score 0.1104
# Epoch  3, CIFAR-10 Batch 1:   cost_score 2.29029 accuracy_score 0.1348
# Epoch  4, CIFAR-10 Batch 1:   cost_score 2.28383 accuracy_score 0.167
# Epoch  5, CIFAR-10 Batch 1:   cost_score 2.27383 accuracy_score 0.1912
# Epoch  6, CIFAR-10 Batch 1:   cost_score 2.25848 accuracy_score 0.1888
# Epoch  7, CIFAR-10 Batch 1:   cost_score 2.23721 accuracy_score 0.1808
# Epoch  8, CIFAR-10 Batch 1:   cost_score 2.20457 accuracy_score 0.1988
# Epoch  9, CIFAR-10 Batch 1:   cost_score 2.15986 accuracy_score 0.2292
# Epoch 10, CIFAR-10 Batch 1:   cost_score 2.1015 accuracy_score 0.2572
# Epoch 11, CIFAR-10 Batch 1:   cost_score 2.0603 accuracy_score 0.2514
# Epoch 12, CIFAR-10 Batch 1:   cost_score 2.02014 accuracy_score 0.263
# Epoch 13, CIFAR-10 Batch 1:   cost_score 1.95379 accuracy_score 0.3002
# Epoch 14, CIFAR-10 Batch 1:   cost_score 1.9469 accuracy_score 0.2912
# Epoch 15, CIFAR-10 Batch 1:   cost_score 1.89928 accuracy_score 0.3238
# Epoch 16, CIFAR-10 Batch 1:   cost_score 1.88046 accuracy_score 0.3268
# Epoch 17, CIFAR-10 Batch 1:   cost_score 1.86243 accuracy_score 0.3356
# Epoch 18, CIFAR-10 Batch 1:   cost_score 1.84514 accuracy_score 0.3456
# Epoch 19, CIFAR-10 Batch 1:   cost_score 1.82626 accuracy_score 0.355
# Epoch 20, CIFAR-10 Batch 1:   cost_score 1.80759 accuracy_score 0.3662
# Epoch 21, CIFAR-10 Batch 1:   cost_score 1.79025 accuracy_score 0.3584
# Epoch 22, CIFAR-10 Batch 1:   cost_score 1.77071 accuracy_score 0.3704
# Epoch 23, CIFAR-10 Batch 1:   cost_score 1.75161 accuracy_score 0.3686
# Epoch 24, CIFAR-10 Batch 1:   cost_score 1.73421 accuracy_score 0.3704
# Epoch 25, CIFAR-10 Batch 1:   cost_score 1.7155 accuracy_score 0.3746
# Epoch 26, CIFAR-10 Batch 1:   cost_score 1.70425 accuracy_score 0.3772
# Epoch 27, CIFAR-10 Batch 1:   cost_score 1.69045 accuracy_score 0.3814
# Epoch 28, CIFAR-10 Batch 1:   cost_score 1.68184 accuracy_score 0.3818
# Epoch 29, CIFAR-10 Batch 1:   cost_score 1.66926 accuracy_score 0.3818
# Epoch 30, CIFAR-10 Batch 1:   cost_score 1.65447 accuracy_score 0.3876
# Epoch 31, CIFAR-10 Batch 1:   cost_score 1.64435 accuracy_score 0.3862
# Epoch 32, CIFAR-10 Batch 1:   cost_score 1.62925 accuracy_score 0.3924
# Epoch 33, CIFAR-10 Batch 1:   cost_score 1.61488 accuracy_score 0.3924
# Epoch 34, CIFAR-10 Batch 1:   cost_score 1.60521 accuracy_score 0.3942
# Epoch 35, CIFAR-10 Batch 1:   cost_score 1.59475 accuracy_score 0.3956
# Epoch 36, CIFAR-10 Batch 1:   cost_score 1.58694 accuracy_score 0.4006
# Epoch 37, CIFAR-10 Batch 1:   cost_score 1.57564 accuracy_score 0.4022
# Epoch 38, CIFAR-10 Batch 1:   cost_score 1.56564 accuracy_score 0.4046
# Epoch 39, CIFAR-10 Batch 1:   cost_score 1.55414 accuracy_score 0.4066
# Epoch 40, CIFAR-10 Batch 1:   cost_score 1.54296 accuracy_score 0.4078
# Epoch 41, CIFAR-10 Batch 1:   cost_score 1.53238 accuracy_score 0.4084
# Epoch 42, CIFAR-10 Batch 1:   cost_score 1.51959 accuracy_score 0.4048
# Epoch 43, CIFAR-10 Batch 1:   cost_score 1.50881 accuracy_score 0.4128
# Epoch 44, CIFAR-10 Batch 1:   cost_score 1.5013 accuracy_score 0.414
# Epoch 45, CIFAR-10 Batch 1:   cost_score 1.49361 accuracy_score 0.4112
# Epoch 46, CIFAR-10 Batch 1:   cost_score 1.48867 accuracy_score 0.4168
# Epoch 47, CIFAR-10 Batch 1:   cost_score 1.47424 accuracy_score 0.414
# Epoch 48, CIFAR-10 Batch 1:   cost_score 1.46593 accuracy_score 0.4188
# Epoch 49, CIFAR-10 Batch 1:   cost_score 1.4534 accuracy_score 0.4122
# Epoch 50, CIFAR-10 Batch 1:   cost_score 1.44166 accuracy_score 0.417
# Epoch 51, CIFAR-10 Batch 1:   cost_score 1.42805 accuracy_score 0.4174
# Epoch 52, CIFAR-10 Batch 1:   cost_score 1.41948 accuracy_score 0.419
# Epoch 53, CIFAR-10 Batch 1:   cost_score 1.41376 accuracy_score 0.4206
# Epoch 54, CIFAR-10 Batch 1:   cost_score 1.40133 accuracy_score 0.4232
# Epoch 55, CIFAR-10 Batch 1:   cost_score 1.39553 accuracy_score 0.428
# Epoch 56, CIFAR-10 Batch 1:   cost_score 1.38554 accuracy_score 0.4268
# Epoch 57, CIFAR-10 Batch 1:   cost_score 1.37464 accuracy_score 0.4266
# Epoch 58, CIFAR-10 Batch 1:   cost_score 1.36476 accuracy_score 0.4312
# Epoch 59, CIFAR-10 Batch 1:   cost_score 1.3524 accuracy_score 0.4296
# Epoch 60, CIFAR-10 Batch 1:   cost_score 1.34201 accuracy_score 0.4336
# Epoch 61, CIFAR-10 Batch 1:   cost_score 1.33362 accuracy_score 0.4366
# Epoch 62, CIFAR-10 Batch 1:   cost_score 1.32704 accuracy_score 0.4368
# Epoch 63, CIFAR-10 Batch 1:   cost_score 1.32083 accuracy_score 0.4414
# Epoch 64, CIFAR-10 Batch 1:   cost_score 1.31427 accuracy_score 0.4448
# Epoch 65, CIFAR-10 Batch 1:   cost_score 1.3059 accuracy_score 0.4424
# Epoch 66, CIFAR-10 Batch 1:   cost_score 1.30057 accuracy_score 0.4446
# Epoch 67, CIFAR-10 Batch 1:   cost_score 1.28586 accuracy_score 0.4442
# Epoch 68, CIFAR-10 Batch 1:   cost_score 1.27576 accuracy_score 0.4454
# Epoch 69, CIFAR-10 Batch 1:   cost_score 1.27034 accuracy_score 0.4458
# Epoch 70, CIFAR-10 Batch 1:   cost_score 1.25914 accuracy_score 0.4492
# Epoch 71, CIFAR-10 Batch 1:   cost_score 1.25199 accuracy_score 0.4502
# Epoch 72, CIFAR-10 Batch 1:   cost_score 1.24401 accuracy_score 0.4522
# Epoch 73, CIFAR-10 Batch 1:   cost_score 1.2351 accuracy_score 0.4534
# Epoch 74, CIFAR-10 Batch 1:   cost_score 1.23241 accuracy_score 0.4498
# Epoch 75, CIFAR-10 Batch 1:   cost_score 1.22198 accuracy_score 0.4534
# Epoch 76, CIFAR-10 Batch 1:   cost_score 1.21238 accuracy_score 0.4562
# Epoch 77, CIFAR-10 Batch 1:   cost_score 1.20483 accuracy_score 0.4584
# Epoch 78, CIFAR-10 Batch 1:   cost_score 1.19756 accuracy_score 0.4582
# Epoch 79, CIFAR-10 Batch 1:   cost_score 1.20037 accuracy_score 0.4546
# Epoch 80, CIFAR-10 Batch 1:   cost_score 1.18064 accuracy_score 0.4612
# Epoch 81, CIFAR-10 Batch 1:   cost_score 1.17663 accuracy_score 0.4626
# Epoch 82, CIFAR-10 Batch 1:   cost_score 1.17188 accuracy_score 0.465
# Epoch 83, CIFAR-10 Batch 1:   cost_score 1.16537 accuracy_score 0.4622
# Epoch 84, CIFAR-10 Batch 1:   cost_score 1.15771 accuracy_score 0.4624
# Epoch 85, CIFAR-10 Batch 1:   cost_score 1.14958 accuracy_score 0.466
# Epoch 86, CIFAR-10 Batch 1:   cost_score 1.14278 accuracy_score 0.467
# Epoch 87, CIFAR-10 Batch 1:   cost_score 1.13933 accuracy_score 0.4682
# Epoch 88, CIFAR-10 Batch 1:   cost_score 1.12526 accuracy_score 0.4712
# Epoch 89, CIFAR-10 Batch 1:   cost_score 1.12129 accuracy_score 0.4684
# Epoch 90, CIFAR-10 Batch 1:   cost_score 1.11623 accuracy_score 0.4682
# Epoch 91, CIFAR-10 Batch 1:   cost_score 1.10553 accuracy_score 0.4712
# Epoch 92, CIFAR-10 Batch 1:   cost_score 1.10952 accuracy_score 0.4692
# Epoch 93, CIFAR-10 Batch 1:   cost_score 1.09008 accuracy_score 0.4746
# Epoch 94, CIFAR-10 Batch 1:   cost_score 1.08893 accuracy_score 0.4738
# Epoch 95, CIFAR-10 Batch 1:   cost_score 1.09222 accuracy_score 0.4704
# Epoch 96, CIFAR-10 Batch 1:   cost_score 1.07572 accuracy_score 0.4774
# Epoch 97, CIFAR-10 Batch 1:   cost_score 1.07306 accuracy_score 0.4726
# Epoch 98, CIFAR-10 Batch 1:   cost_score 1.06759 accuracy_score 0.479
# Epoch 99, CIFAR-10 Batch 1:   cost_score 1.06652 accuracy_score 0.4794
# Epoch 100, CIFAR-10 Batch 1:   cost_score 1.06474 accuracy_score 0.477
# Epoch 101, CIFAR-10 Batch 1:   cost_score 1.05225 accuracy_score 0.4798
# Epoch 102, CIFAR-10 Batch 1:   cost_score 1.06222 accuracy_score 0.4758
# Epoch 103, CIFAR-10 Batch 1:   cost_score 1.0437 accuracy_score 0.4802
# Epoch 104, CIFAR-10 Batch 1:   cost_score 1.0394 accuracy_score 0.4794
# Epoch 105, CIFAR-10 Batch 1:   cost_score 1.02718 accuracy_score 0.4834
# Epoch 106, CIFAR-10 Batch 1:   cost_score 1.01708 accuracy_score 0.484
# Epoch 107, CIFAR-10 Batch 1:   cost_score 1.01597 accuracy_score 0.4838
# Epoch 108, CIFAR-10 Batch 1:   cost_score 1.00601 accuracy_score 0.4866
# Epoch 109, CIFAR-10 Batch 1:   cost_score 0.997192 accuracy_score 0.4838
# Epoch 110, CIFAR-10 Batch 1:   cost_score 0.985397 accuracy_score 0.4896
# Epoch 111, CIFAR-10 Batch 1:   cost_score 0.984783 accuracy_score 0.4866
# Epoch 112, CIFAR-10 Batch 1:   cost_score 0.97497 accuracy_score 0.4874
# Epoch 113, CIFAR-10 Batch 1:   cost_score 0.970287 accuracy_score 0.4912
# Epoch 114, CIFAR-10 Batch 1:   cost_score 0.963336 accuracy_score 0.4906
# Epoch 115, CIFAR-10 Batch 1:   cost_score 0.962826 accuracy_score 0.491
# Epoch 116, CIFAR-10 Batch 1:   cost_score 0.964517 accuracy_score 0.4886
# Epoch 117, CIFAR-10 Batch 1:   cost_score 0.954669 accuracy_score 0.4888
# Epoch 118, CIFAR-10 Batch 1:   cost_score 0.971419 accuracy_score 0.4844
# Epoch 119, CIFAR-10 Batch 1:   cost_score 0.955558 accuracy_score 0.4902
# Epoch 120, CIFAR-10 Batch 1:   cost_score 0.953936 accuracy_score 0.4898
# Epoch 121, CIFAR-10 Batch 1:   cost_score 0.934066 accuracy_score 0.4942
# Epoch 122, CIFAR-10 Batch 1:   cost_score 0.933722 accuracy_score 0.491
# Epoch 123, CIFAR-10 Batch 1:   cost_score 0.929115 accuracy_score 0.4888
# Epoch 124, CIFAR-10 Batch 1:   cost_score 0.9206 accuracy_score 0.496
# Epoch 125, CIFAR-10 Batch 1:   cost_score 0.913986 accuracy_score 0.4958
# Epoch 126, CIFAR-10 Batch 1:   cost_score 0.911222 accuracy_score 0.4968
# Epoch 127, CIFAR-10 Batch 1:   cost_score 0.901602 accuracy_score 0.4948
# Epoch 128, CIFAR-10 Batch 1:   cost_score 0.897617 accuracy_score 0.4948
# Epoch 129, CIFAR-10 Batch 1:   cost_score 0.890934 accuracy_score 0.4972
# Epoch 130, CIFAR-10 Batch 1:   cost_score 0.88716 accuracy_score 0.4964
# Epoch 131, CIFAR-10 Batch 1:   cost_score 0.889894 accuracy_score 0.497
# Epoch 132, CIFAR-10 Batch 1:   cost_score 0.875772 accuracy_score 0.4982
# Epoch 133, CIFAR-10 Batch 1:   cost_score 0.884663 accuracy_score 0.497
# Epoch 134, CIFAR-10 Batch 1:   cost_score 0.869282 accuracy_score 0.5002
# Epoch 135, CIFAR-10 Batch 1:   cost_score 0.86885 accuracy_score 0.4992
# Epoch 136, CIFAR-10 Batch 1:   cost_score 0.861867 accuracy_score 0.5012
# Epoch 137, CIFAR-10 Batch 1:   cost_score 0.858564 accuracy_score 0.5036
# Epoch 138, CIFAR-10 Batch 1:   cost_score 0.847939 accuracy_score 0.5064
# Epoch 139, CIFAR-10 Batch 1:   cost_score 0.846291 accuracy_score 0.5024
# Epoch 140, CIFAR-10 Batch 1:   cost_score 0.840503 accuracy_score 0.5022
# Epoch 141, CIFAR-10 Batch 1:   cost_score 0.830477 accuracy_score 0.5014
# Epoch 142, CIFAR-10 Batch 1:   cost_score 0.832644 accuracy_score 0.5024
# Epoch 143, CIFAR-10 Batch 1:   cost_score 0.823818 accuracy_score 0.5036
# Epoch 144, CIFAR-10 Batch 1:   cost_score 0.822961 accuracy_score 0.5016
# Epoch 145, CIFAR-10 Batch 1:   cost_score 0.812085 accuracy_score 0.5032
# Epoch 146, CIFAR-10 Batch 1:   cost_score 0.808938 accuracy_score 0.507
# Epoch 147, CIFAR-10 Batch 1:   cost_score 0.810376 accuracy_score 0.5036
# Epoch 148, CIFAR-10 Batch 1:   cost_score 0.803057 accuracy_score 0.5048
# Epoch 149, CIFAR-10 Batch 1:   cost_score 0.798753 accuracy_score 0.51
# Epoch 150, CIFAR-10 Batch 1:   cost_score 0.791866 accuracy_score 0.5098
# Epoch 151, CIFAR-10 Batch 1:   cost_score 0.787531 accuracy_score 0.5048
# Epoch 152, CIFAR-10 Batch 1:   cost_score 0.78576 accuracy_score 0.5058
# Epoch 153, CIFAR-10 Batch 1:   cost_score 0.77619 accuracy_score 0.5106
# Epoch 154, CIFAR-10 Batch 1:   cost_score 0.771168 accuracy_score 0.5112
# Epoch 155, CIFAR-10 Batch 1:   cost_score 0.775781 accuracy_score 0.5086
# Epoch 156, CIFAR-10 Batch 1:   cost_score 0.761488 accuracy_score 0.5128
# Epoch 157, CIFAR-10 Batch 1:   cost_score 0.759253 accuracy_score 0.5128
# Epoch 158, CIFAR-10 Batch 1:   cost_score 0.760972 accuracy_score 0.508
# Epoch 159, CIFAR-10 Batch 1:   cost_score 0.754599 accuracy_score 0.5066
# Epoch 160, CIFAR-10 Batch 1:   cost_score 0.742389 accuracy_score 0.5106
# Epoch 161, CIFAR-10 Batch 1:   cost_score 0.74583 accuracy_score 0.5084
# Epoch 162, CIFAR-10 Batch 1:   cost_score 0.734178 accuracy_score 0.5094
# Epoch 163, CIFAR-10 Batch 1:   cost_score 0.733336 accuracy_score 0.5098
# Epoch 164, CIFAR-10 Batch 1:   cost_score 0.725149 accuracy_score 0.5104
# Epoch 165, CIFAR-10 Batch 1:   cost_score 0.724688 accuracy_score 0.5114
# Epoch 166, CIFAR-10 Batch 1:   cost_score 0.723218 accuracy_score 0.5102
# Epoch 167, CIFAR-10 Batch 1:   cost_score 0.715964 accuracy_score 0.5086
# Epoch 168, CIFAR-10 Batch 1:   cost_score 0.717483 accuracy_score 0.509
# Epoch 169, CIFAR-10 Batch 1:   cost_score 0.706278 accuracy_score 0.5098
# Epoch 170, CIFAR-10 Batch 1:   cost_score 0.700426 accuracy_score 0.5142
# Epoch 171, CIFAR-10 Batch 1:   cost_score 0.695306 accuracy_score 0.513
# Epoch 172, CIFAR-10 Batch 1:   cost_score 0.69355 accuracy_score 0.5156
# Epoch 173, CIFAR-10 Batch 1:   cost_score 0.689186 accuracy_score 0.5172
# Epoch 174, CIFAR-10 Batch 1:   cost_score 0.683546 accuracy_score 0.513
# Epoch 175, CIFAR-10 Batch 1:   cost_score 0.676879 accuracy_score 0.5112
# Epoch 176, CIFAR-10 Batch 1:   cost_score 0.672979 accuracy_score 0.5122
# Epoch 177, CIFAR-10 Batch 1:   cost_score 0.676689 accuracy_score 0.5142
# Epoch 178, CIFAR-10 Batch 1:   cost_score 0.665619 accuracy_score 0.5124
# Epoch 179, CIFAR-10 Batch 1:   cost_score 0.667334 accuracy_score 0.5132
# Epoch 180, CIFAR-10 Batch 1:   cost_score 0.662172 accuracy_score 0.5138
# Epoch 181, CIFAR-10 Batch 1:   cost_score 0.658632 accuracy_score 0.5168
# Epoch 182, CIFAR-10 Batch 1:   cost_score 0.652061 accuracy_score 0.5166
# Epoch 183, CIFAR-10 Batch 1:   cost_score 0.652925 accuracy_score 0.5134
# Epoch 184, CIFAR-10 Batch 1:   cost_score 0.640258 accuracy_score 0.5168
# Epoch 185, CIFAR-10 Batch 1:   cost_score 0.638777 accuracy_score 0.5166
# Epoch 186, CIFAR-10 Batch 1:   cost_score 0.633777 accuracy_score 0.5158
# Epoch 187, CIFAR-10 Batch 1:   cost_score 0.631655 accuracy_score 0.5156
# Epoch 188, CIFAR-10 Batch 1:   cost_score 0.62807 accuracy_score 0.5184
# Epoch 189, CIFAR-10 Batch 1:   cost_score 0.624346 accuracy_score 0.5172
# Epoch 190, CIFAR-10 Batch 1:   cost_score 0.625039 accuracy_score 0.5164
# Epoch 191, CIFAR-10 Batch 1:   cost_score 0.615338 accuracy_score 0.5144
# Epoch 192, CIFAR-10 Batch 1:   cost_score 0.611934 accuracy_score 0.5112
# Epoch 193, CIFAR-10 Batch 1:   cost_score 0.615711 accuracy_score 0.5116
# Epoch 194, CIFAR-10 Batch 1:   cost_score 0.606118 accuracy_score 0.5148
# Epoch 195, CIFAR-10 Batch 1:   cost_score 0.592544 accuracy_score 0.5162
# Epoch 196, CIFAR-10 Batch 1:   cost_score 0.599951 accuracy_score 0.5152
# Epoch 197, CIFAR-10 Batch 1:   cost_score 0.587511 accuracy_score 0.5178
# Epoch 198, CIFAR-10 Batch 1:   cost_score 0.590803 accuracy_score 0.5188
# Epoch 199, CIFAR-10 Batch 1:   cost_score 0.589629 accuracy_score 0.52
# Epoch 200, CIFAR-10 Batch 1:   cost_score 0.58094 accuracy_score 0.5182
# Epoch 201, CIFAR-10 Batch 1:   cost_score 0.587554 accuracy_score 0.5182
# Epoch 202, CIFAR-10 Batch 1:   cost_score 0.577906 accuracy_score 0.5174
# Epoch 203, CIFAR-10 Batch 1:   cost_score 0.572906 accuracy_score 0.5186
# Epoch 204, CIFAR-10 Batch 1:   cost_score 0.576167 accuracy_score 0.519
# Epoch 205, CIFAR-10 Batch 1:   cost_score 0.566868 accuracy_score 0.5204
# Epoch 206, CIFAR-10 Batch 1:   cost_score 0.567271 accuracy_score 0.52
# Epoch 207, CIFAR-10 Batch 1:   cost_score 0.571652 accuracy_score 0.5182
# Epoch 208, CIFAR-10 Batch 1:   cost_score 0.558327 accuracy_score 0.5226
# Epoch 209, CIFAR-10 Batch 1:   cost_score 0.561227 accuracy_score 0.521
# Epoch 210, CIFAR-10 Batch 1:   cost_score 0.549552 accuracy_score 0.5266
# Epoch 211, CIFAR-10 Batch 1:   cost_score 0.547095 accuracy_score 0.5232
# Epoch 212, CIFAR-10 Batch 1:   cost_score 0.546218 accuracy_score 0.522
# Epoch 213, CIFAR-10 Batch 1:   cost_score 0.538467 accuracy_score 0.5244
# Epoch 214, CIFAR-10 Batch 1:   cost_score 0.537878 accuracy_score 0.5244
# Epoch 215, CIFAR-10 Batch 1:   cost_score 0.534751 accuracy_score 0.5226
# Epoch 216, CIFAR-10 Batch 1:   cost_score 0.531008 accuracy_score 0.5218
# Epoch 217, CIFAR-10 Batch 1:   cost_score 0.529912 accuracy_score 0.5214
# Epoch 218, CIFAR-10 Batch 1:   cost_score 0.522294 accuracy_score 0.5214
# Epoch 219, CIFAR-10 Batch 1:   cost_score 0.51838 accuracy_score 0.525
# Epoch 220, CIFAR-10 Batch 1:   cost_score 0.519476 accuracy_score 0.524
# Epoch 221, CIFAR-10 Batch 1:   cost_score 0.509737 accuracy_score 0.5248
# Epoch 222, CIFAR-10 Batch 1:   cost_score 0.51498 accuracy_score 0.5234
# Epoch 223, CIFAR-10 Batch 1:   cost_score 0.50719 accuracy_score 0.5236
# Epoch 224, CIFAR-10 Batch 1:   cost_score 0.504986 accuracy_score 0.5226
# Epoch 225, CIFAR-10 Batch 1:   cost_score 0.500917 accuracy_score 0.5266
# Epoch 226, CIFAR-10 Batch 1:   cost_score 0.493359 accuracy_score 0.5274
# Epoch 227, CIFAR-10 Batch 1:   cost_score 0.493595 accuracy_score 0.5244
# Epoch 228, CIFAR-10 Batch 1:   cost_score 0.489876 accuracy_score 0.5294
# Epoch 229, CIFAR-10 Batch 1:   cost_score 0.485303 accuracy_score 0.5252
# Epoch 230, CIFAR-10 Batch 1:   cost_score 0.487916 accuracy_score 0.5284
# Epoch 231, CIFAR-10 Batch 1:   cost_score 0.488973 accuracy_score 0.5256
# Epoch 232, CIFAR-10 Batch 1:   cost_score 0.481487 accuracy_score 0.527
# Epoch 233, CIFAR-10 Batch 1:   cost_score 0.476739 accuracy_score 0.5254
# Epoch 234, CIFAR-10 Batch 1:   cost_score 0.475304 accuracy_score 0.5266
# Epoch 235, CIFAR-10 Batch 1:   cost_score 0.471821 accuracy_score 0.5284
# Epoch 236, CIFAR-10 Batch 1:   cost_score 0.463478 accuracy_score 0.529
# Epoch 237, CIFAR-10 Batch 1:   cost_score 0.462659 accuracy_score 0.5276
# Epoch 238, CIFAR-10 Batch 1:   cost_score 0.463895 accuracy_score 0.5246
# Epoch 239, CIFAR-10 Batch 1:   cost_score 0.462505 accuracy_score 0.526
# Epoch 240, CIFAR-10 Batch 1:   cost_score 0.458342 accuracy_score 0.5266
# Epoch 241, CIFAR-10 Batch 1:   cost_score 0.453626 accuracy_score 0.5282
# Epoch 242, CIFAR-10 Batch 1:   cost_score 0.455572 accuracy_score 0.5268
# Epoch 243, CIFAR-10 Batch 1:   cost_score 0.450954 accuracy_score 0.5254
# Epoch 244, CIFAR-10 Batch 1:   cost_score 0.443419 accuracy_score 0.5248
# Epoch 245, CIFAR-10 Batch 1:   cost_score 0.444164 accuracy_score 0.5266
# Epoch 246, CIFAR-10 Batch 1:   cost_score 0.439382 accuracy_score 0.5288
# Epoch 247, CIFAR-10 Batch 1:   cost_score 0.439199 accuracy_score 0.5286
# Epoch 248, CIFAR-10 Batch 1:   cost_score 0.443784 accuracy_score 0.5272
# Epoch 249, CIFAR-10 Batch 1:   cost_score 0.431283 accuracy_score 0.5292
# Epoch 250, CIFAR-10 Batch 1:   cost_score 0.433673 accuracy_score 0.5282
# Epoch 251, CIFAR-10 Batch 1:   cost_score 0.425522 accuracy_score 0.5298
# Epoch 252, CIFAR-10 Batch 1:   cost_score 0.425063 accuracy_score 0.5326
# Epoch 253, CIFAR-10 Batch 1:   cost_score 0.440434 accuracy_score 0.5224
# Epoch 254, CIFAR-10 Batch 1:   cost_score 0.422574 accuracy_score 0.5286
# Epoch 255, CIFAR-10 Batch 1:   cost_score 0.424028 accuracy_score 0.5254
# Epoch 256, CIFAR-10 Batch 1:   cost_score 0.419967 accuracy_score 0.5298
# Epoch 257, CIFAR-10 Batch 1:   cost_score 0.418396 accuracy_score 0.528
# Epoch 258, CIFAR-10 Batch 1:   cost_score 0.418128 accuracy_score 0.5262
# Epoch 259, CIFAR-10 Batch 1:   cost_score 0.418257 accuracy_score 0.5256
# Epoch 260, CIFAR-10 Batch 1:   cost_score 0.409971 accuracy_score 0.528
# Epoch 261, CIFAR-10 Batch 1:   cost_score 0.411336 accuracy_score 0.5284
# Epoch 262, CIFAR-10 Batch 1:   cost_score 0.400682 accuracy_score 0.5308
# Epoch 263, CIFAR-10 Batch 1:   cost_score 0.406068 accuracy_score 0.5304
# Epoch 264, CIFAR-10 Batch 1:   cost_score 0.404731 accuracy_score 0.5312
# Epoch 265, CIFAR-10 Batch 1:   cost_score 0.406655 accuracy_score 0.5298
# Epoch 266, CIFAR-10 Batch 1:   cost_score 0.39859 accuracy_score 0.532
# Epoch 267, CIFAR-10 Batch 1:   cost_score 0.394548 accuracy_score 0.5322
# Epoch 268, CIFAR-10 Batch 1:   cost_score 0.391854 accuracy_score 0.5336
# Epoch 269, CIFAR-10 Batch 1:   cost_score 0.397748 accuracy_score 0.5282
# Epoch 270, CIFAR-10 Batch 1:   cost_score 0.388474 accuracy_score 0.5296
# Epoch 271, CIFAR-10 Batch 1:   cost_score 0.392681 accuracy_score 0.5264
# Epoch 272, CIFAR-10 Batch 1:   cost_score 0.383631 accuracy_score 0.5302
# Epoch 273, CIFAR-10 Batch 1:   cost_score 0.379289 accuracy_score 0.5302
# Epoch 274, CIFAR-10 Batch 1:   cost_score 0.387365 accuracy_score 0.5312
# Epoch 275, CIFAR-10 Batch 1:   cost_score 0.374165 accuracy_score 0.5338
# Epoch 276, CIFAR-10 Batch 1:   cost_score 0.373722 accuracy_score 0.533
# Epoch 277, CIFAR-10 Batch 1:   cost_score 0.376284 accuracy_score 0.5308
# Epoch 278, CIFAR-10 Batch 1:   cost_score 0.36826 accuracy_score 0.5356
# Epoch 279, CIFAR-10 Batch 1:   cost_score 0.373409 accuracy_score 0.5328
# Epoch 280, CIFAR-10 Batch 1:   cost_score 0.371192 accuracy_score 0.5342
# Epoch 281, CIFAR-10 Batch 1:   cost_score 0.36716 accuracy_score 0.5304
# Epoch 282, CIFAR-10 Batch 1:   cost_score 0.368957 accuracy_score 0.5306
# Epoch 283, CIFAR-10 Batch 1:   cost_score 0.359615 accuracy_score 0.5336
# Epoch 284, CIFAR-10 Batch 1:   cost_score 0.354855 accuracy_score 0.533
# Epoch 285, CIFAR-10 Batch 1:   cost_score 0.356855 accuracy_score 0.5318
# Epoch 286, CIFAR-10 Batch 1:   cost_score 0.350004 accuracy_score 0.5312
# Epoch 287, CIFAR-10 Batch 1:   cost_score 0.347107 accuracy_score 0.533
# Epoch 288, CIFAR-10 Batch 1:   cost_score 0.34985 accuracy_score 0.5354
# Epoch 289, CIFAR-10 Batch 1:   cost_score 0.344803 accuracy_score 0.537
# Epoch 290, CIFAR-10 Batch 1:   cost_score 0.34811 accuracy_score 0.5368
# Epoch 291, CIFAR-10 Batch 1:   cost_score 0.34741 accuracy_score 0.5326
# Epoch 292, CIFAR-10 Batch 1:   cost_score 0.340414 accuracy_score 0.5322
# Epoch 293, CIFAR-10 Batch 1:   cost_score 0.339365 accuracy_score 0.5366
# Epoch 294, CIFAR-10 Batch 1:   cost_score 0.343469 accuracy_score 0.5312
# Epoch 295, CIFAR-10 Batch 1:   cost_score 0.334474 accuracy_score 0.5376
# Epoch 296, CIFAR-10 Batch 1:   cost_score 0.336065 accuracy_score 0.531
# Epoch 297, CIFAR-10 Batch 1:   cost_score 0.329596 accuracy_score 0.5364
# Epoch 298, CIFAR-10 Batch 1:   cost_score 0.327013 accuracy_score 0.5376
# Epoch 299, CIFAR-10 Batch 1:   cost_score 0.323869 accuracy_score 0.5386
# Epoch 300, CIFAR-10 Batch 1:   cost_score 0.319414 accuracy_score 0.539
# Epoch 301, CIFAR-10 Batch 1:   cost_score 0.317977 accuracy_score 0.5408
# Epoch 302, CIFAR-10 Batch 1:   cost_score 0.31784 accuracy_score 0.5398
# Epoch 303, CIFAR-10 Batch 1:   cost_score 0.318373 accuracy_score 0.5388
# Epoch 304, CIFAR-10 Batch 1:   cost_score 0.317108 accuracy_score 0.5372
# Epoch 305, CIFAR-10 Batch 1:   cost_score 0.315702 accuracy_score 0.5382
# Epoch 306, CIFAR-10 Batch 1:   cost_score 0.319125 accuracy_score 0.5348
# Epoch 307, CIFAR-10 Batch 1:   cost_score 0.310602 accuracy_score 0.5402
# Epoch 308, CIFAR-10 Batch 1:   cost_score 0.309548 accuracy_score 0.54
# Epoch 309, CIFAR-10 Batch 1:   cost_score 0.309816 accuracy_score 0.5372
# Epoch 310, CIFAR-10 Batch 1:   cost_score 0.305612 accuracy_score 0.5384
# Epoch 311, CIFAR-10 Batch 1:   cost_score 0.307496 accuracy_score 0.5354
# Epoch 312, CIFAR-10 Batch 1:   cost_score 0.302757 accuracy_score 0.5376
# Epoch 313, CIFAR-10 Batch 1:   cost_score 0.298155 accuracy_score 0.539
# Epoch 314, CIFAR-10 Batch 1:   cost_score 0.301917 accuracy_score 0.5394
# Epoch 315, CIFAR-10 Batch 1:   cost_score 0.295696 accuracy_score 0.536
# Epoch 316, CIFAR-10 Batch 1:   cost_score 0.295139 accuracy_score 0.5338
# Epoch 317, CIFAR-10 Batch 1:   cost_score 0.29353 accuracy_score 0.5374
# Epoch 318, CIFAR-10 Batch 1:   cost_score 0.286225 accuracy_score 0.5382
# Epoch 319, CIFAR-10 Batch 1:   cost_score 0.29596 accuracy_score 0.5372
# Epoch 320, CIFAR-10 Batch 1:   cost_score 0.287618 accuracy_score 0.5344
# Epoch 321, CIFAR-10 Batch 1:   cost_score 0.288051 accuracy_score 0.5386
# Epoch 322, CIFAR-10 Batch 1:   cost_score 0.289049 accuracy_score 0.5364
# Epoch 323, CIFAR-10 Batch 1:   cost_score 0.283395 accuracy_score 0.5412
# Epoch 324, CIFAR-10 Batch 1:   cost_score 0.287327 accuracy_score 0.542
# Epoch 325, CIFAR-10 Batch 1:   cost_score 0.286835 accuracy_score 0.5396
# Epoch 326, CIFAR-10 Batch 1:   cost_score 0.286831 accuracy_score 0.535
# Epoch 327, CIFAR-10 Batch 1:   cost_score 0.286272 accuracy_score 0.5362
# Epoch 328, CIFAR-10 Batch 1:   cost_score 0.284088 accuracy_score 0.535
# Epoch 329, CIFAR-10 Batch 1:   cost_score 0.277813 accuracy_score 0.538
# Epoch 330, CIFAR-10 Batch 1:   cost_score 0.277858 accuracy_score 0.5372
# Epoch 331, CIFAR-10 Batch 1:   cost_score 0.278137 accuracy_score 0.5382
# Epoch 332, CIFAR-10 Batch 1:   cost_score 0.27713 accuracy_score 0.5368
# Epoch 333, CIFAR-10 Batch 1:   cost_score 0.271141 accuracy_score 0.5436
# Epoch 334, CIFAR-10 Batch 1:   cost_score 0.272398 accuracy_score 0.5374
# Epoch 335, CIFAR-10 Batch 1:   cost_score 0.275144 accuracy_score 0.5384
# Epoch 336, CIFAR-10 Batch 1:   cost_score 0.271986 accuracy_score 0.539
# Epoch 337, CIFAR-10 Batch 1:   cost_score 0.274782 accuracy_score 0.5394
# Epoch 338, CIFAR-10 Batch 1:   cost_score 0.269682 accuracy_score 0.5418
# Epoch 339, CIFAR-10 Batch 1:   cost_score 0.267293 accuracy_score 0.5422
# Epoch 340, CIFAR-10 Batch 1:   cost_score 0.270869 accuracy_score 0.5408
# Epoch 341, CIFAR-10 Batch 1:   cost_score 0.263304 accuracy_score 0.545
# Epoch 342, CIFAR-10 Batch 1:   cost_score 0.261964 accuracy_score 0.5438
# Epoch 343, CIFAR-10 Batch 1:   cost_score 0.26098 accuracy_score 0.5428
# Epoch 344, CIFAR-10 Batch 1:   cost_score 0.254324 accuracy_score 0.5466
# Epoch 345, CIFAR-10 Batch 1:   cost_score 0.259948 accuracy_score 0.5388
# Epoch 346, CIFAR-10 Batch 1:   cost_score 0.259318 accuracy_score 0.5378
# Epoch 347, CIFAR-10 Batch 1:   cost_score 0.256755 accuracy_score 0.535
# Epoch 348, CIFAR-10 Batch 1:   cost_score 0.253899 accuracy_score 0.5398
# Epoch 349, CIFAR-10 Batch 1:   cost_score 0.257221 accuracy_score 0.5352
# Epoch 350, CIFAR-10 Batch 1:   cost_score 0.251448 accuracy_score 0.5406
# Epoch 351, CIFAR-10 Batch 1:   cost_score 0.248914 accuracy_score 0.541
# Epoch 352, CIFAR-10 Batch 1:   cost_score 0.247759 accuracy_score 0.544
# Epoch 353, CIFAR-10 Batch 1:   cost_score 0.248846 accuracy_score 0.5438
# Epoch 354, CIFAR-10 Batch 1:   cost_score 0.247018 accuracy_score 0.546
# Epoch 355, CIFAR-10 Batch 1:   cost_score 0.243534 accuracy_score 0.5446
# Epoch 356, CIFAR-10 Batch 1:   cost_score 0.241733 accuracy_score 0.5464
# Epoch 357, CIFAR-10 Batch 1:   cost_score 0.237194 accuracy_score 0.5472
# Epoch 358, CIFAR-10 Batch 1:   cost_score 0.245268 accuracy_score 0.5444
# Epoch 359, CIFAR-10 Batch 1:   cost_score 0.23844 accuracy_score 0.5458
# Epoch 360, CIFAR-10 Batch 1:   cost_score 0.236136 accuracy_score 0.5418
# Epoch 361, CIFAR-10 Batch 1:   cost_score 0.238311 accuracy_score 0.5432
# Epoch 362, CIFAR-10 Batch 1:   cost_score 0.239075 accuracy_score 0.5412
# Epoch 363, CIFAR-10 Batch 1:   cost_score 0.240443 accuracy_score 0.5426
# Epoch 364, CIFAR-10 Batch 1:   cost_score 0.239269 accuracy_score 0.5426
# Epoch 365, CIFAR-10 Batch 1:   cost_score 0.232289 accuracy_score 0.5452
# Epoch 366, CIFAR-10 Batch 1:   cost_score 0.233068 accuracy_score 0.5452
# Epoch 367, CIFAR-10 Batch 1:   cost_score 0.232063 accuracy_score 0.5458
# Epoch 368, CIFAR-10 Batch 1:   cost_score 0.226525 accuracy_score 0.5482
# Epoch 369, CIFAR-10 Batch 1:   cost_score 0.225701 accuracy_score 0.544
# Epoch 370, CIFAR-10 Batch 1:   cost_score 0.223215 accuracy_score 0.5466
# Epoch 371, CIFAR-10 Batch 1:   cost_score 0.222507 accuracy_score 0.5478
# Epoch 372, CIFAR-10 Batch 1:   cost_score 0.225037 accuracy_score 0.5462
# Epoch 373, CIFAR-10 Batch 1:   cost_score 0.222242 accuracy_score 0.547
# Epoch 374, CIFAR-10 Batch 1:   cost_score 0.222564 accuracy_score 0.5458
# Epoch 375, CIFAR-10 Batch 1:   cost_score 0.223666 accuracy_score 0.5458
# Epoch 376, CIFAR-10 Batch 1:   cost_score 0.218234 accuracy_score 0.547
# Epoch 377, CIFAR-10 Batch 1:   cost_score 0.219713 accuracy_score 0.5438
# Epoch 378, CIFAR-10 Batch 1:   cost_score 0.220171 accuracy_score 0.5432
# Epoch 379, CIFAR-10 Batch 1:   cost_score 0.218615 accuracy_score 0.5446
# Epoch 380, CIFAR-10 Batch 1:   cost_score 0.217556 accuracy_score 0.5468
# Epoch 381, CIFAR-10 Batch 1:   cost_score 0.211247 accuracy_score 0.5482
# Epoch 382, CIFAR-10 Batch 1:   cost_score 0.209905 accuracy_score 0.5476
# Epoch 383, CIFAR-10 Batch 1:   cost_score 0.212569 accuracy_score 0.5472
# Epoch 384, CIFAR-10 Batch 1:   cost_score 0.210222 accuracy_score 0.5478
# Epoch 385, CIFAR-10 Batch 1:   cost_score 0.210923 accuracy_score 0.5488
# Epoch 386, CIFAR-10 Batch 1:   cost_score 0.210812 accuracy_score 0.547
# Epoch 387, CIFAR-10 Batch 1:   cost_score 0.211861 accuracy_score 0.5502
# Epoch 388, CIFAR-10 Batch 1:   cost_score 0.209548 accuracy_score 0.5492
# Epoch 389, CIFAR-10 Batch 1:   cost_score 0.204826 accuracy_score 0.5472
# Epoch 390, CIFAR-10 Batch 1:   cost_score 0.208599 accuracy_score 0.5498
# Epoch 391, CIFAR-10 Batch 1:   cost_score 0.203775 accuracy_score 0.5454
# Epoch 392, CIFAR-10 Batch 1:   cost_score 0.200162 accuracy_score 0.5474
# Epoch 393, CIFAR-10 Batch 1:   cost_score 0.200902 accuracy_score 0.549
# Epoch 394, CIFAR-10 Batch 1:   cost_score 0.200549 accuracy_score 0.5472
# Epoch 395, CIFAR-10 Batch 1:   cost_score 0.199222 accuracy_score 0.5496
# Epoch 396, CIFAR-10 Batch 1:   cost_score 0.199383 accuracy_score 0.546
# Epoch 397, CIFAR-10 Batch 1:   cost_score 0.197905 accuracy_score 0.5488
# Epoch 398, CIFAR-10 Batch 1:   cost_score 0.196789 accuracy_score 0.5478
# Epoch 399, CIFAR-10 Batch 1:   cost_score 0.195038 accuracy_score 0.549
# Epoch 400, CIFAR-10 Batch 1:   cost_score 0.19225 accuracy_score 0.5494
# Epoch 401, CIFAR-10 Batch 1:   cost_score 0.195546 accuracy_score 0.543
# Epoch 402, CIFAR-10 Batch 1:   cost_score 0.198257 accuracy_score 0.546
# Epoch 403, CIFAR-10 Batch 1:   cost_score 0.194468 accuracy_score 0.5434
# Epoch 404, CIFAR-10 Batch 1:   cost_score 0.192917 accuracy_score 0.551
# Epoch 405, CIFAR-10 Batch 1:   cost_score 0.193033 accuracy_score 0.5468
# Epoch 406, CIFAR-10 Batch 1:   cost_score 0.190538 accuracy_score 0.5496
# Epoch 407, CIFAR-10 Batch 1:   cost_score 0.19155 accuracy_score 0.5482
# Epoch 408, CIFAR-10 Batch 1:   cost_score 0.186712 accuracy_score 0.5492
# Epoch 409, CIFAR-10 Batch 1:   cost_score 0.184852 accuracy_score 0.5458
# Epoch 410, CIFAR-10 Batch 1:   cost_score 0.184474 accuracy_score 0.5476
# Epoch 411, CIFAR-10 Batch 1:   cost_score 0.186378 accuracy_score 0.544
# Epoch 412, CIFAR-10 Batch 1:   cost_score 0.18332 accuracy_score 0.5474
# Epoch 413, CIFAR-10 Batch 1:   cost_score 0.188337 accuracy_score 0.5468
# Epoch 414, CIFAR-10 Batch 1:   cost_score 0.18517 accuracy_score 0.5496
# Epoch 415, CIFAR-10 Batch 1:   cost_score 0.181484 accuracy_score 0.5464
# Epoch 416, CIFAR-10 Batch 1:   cost_score 0.18635 accuracy_score 0.5446
# Epoch 417, CIFAR-10 Batch 1:   cost_score 0.183259 accuracy_score 0.552
# Epoch 418, CIFAR-10 Batch 1:   cost_score 0.186891 accuracy_score 0.5418
# Epoch 419, CIFAR-10 Batch 1:   cost_score 0.187674 accuracy_score 0.5514
# Epoch 420, CIFAR-10 Batch 1:   cost_score 0.182485 accuracy_score 0.5466
# Epoch 421, CIFAR-10 Batch 1:   cost_score 0.181144 accuracy_score 0.5524
# Epoch 422, CIFAR-10 Batch 1:   cost_score 0.179107 accuracy_score 0.5504
# Epoch 423, CIFAR-10 Batch 1:   cost_score 0.178855 accuracy_score 0.5478
# Epoch 424, CIFAR-10 Batch 1:   cost_score 0.177938 accuracy_score 0.5498
# Epoch 425, CIFAR-10 Batch 1:   cost_score 0.17393 accuracy_score 0.546
# Epoch 426, CIFAR-10 Batch 1:   cost_score 0.17366 accuracy_score 0.5508
# Epoch 427, CIFAR-10 Batch 1:   cost_score 0.17541 accuracy_score 0.5506
# Epoch 428, CIFAR-10 Batch 1:   cost_score 0.174623 accuracy_score 0.546
# Epoch 429, CIFAR-10 Batch 1:   cost_score 0.171116 accuracy_score 0.548
# Epoch 430, CIFAR-10 Batch 1:   cost_score 0.16871 accuracy_score 0.5506
# Epoch 431, CIFAR-10 Batch 1:   cost_score 0.166786 accuracy_score 0.5512
# Epoch 432, CIFAR-10 Batch 1:   cost_score 0.170388 accuracy_score 0.5538
# Epoch 433, CIFAR-10 Batch 1:   cost_score 0.168623 accuracy_score 0.5532
# Epoch 434, CIFAR-10 Batch 1:   cost_score 0.166821 accuracy_score 0.5524
# Epoch 435, CIFAR-10 Batch 1:   cost_score 0.166621 accuracy_score 0.5536
# Epoch 436, CIFAR-10 Batch 1:   cost_score 0.167172 accuracy_score 0.5482
# Epoch 437, CIFAR-10 Batch 1:   cost_score 0.169658 accuracy_score 0.5516
# Epoch 438, CIFAR-10 Batch 1:   cost_score 0.164641 accuracy_score 0.5526
# Epoch 439, CIFAR-10 Batch 1:   cost_score 0.164101 accuracy_score 0.554
# Epoch 440, CIFAR-10 Batch 1:   cost_score 0.162375 accuracy_score 0.5502
# Epoch 441, CIFAR-10 Batch 1:   cost_score 0.16349 accuracy_score 0.5534
# Epoch 442, CIFAR-10 Batch 1:   cost_score 0.163605 accuracy_score 0.5504
# Epoch 443, CIFAR-10 Batch 1:   cost_score 0.161364 accuracy_score 0.5488
# Epoch 444, CIFAR-10 Batch 1:   cost_score 0.16097 accuracy_score 0.5488
# Epoch 445, CIFAR-10 Batch 1:   cost_score 0.163648 accuracy_score 0.5512
# Epoch 446, CIFAR-10 Batch 1:   cost_score 0.16339 accuracy_score 0.5534
# Epoch 447, CIFAR-10 Batch 1:   cost_score 0.163588 accuracy_score 0.5518
# Epoch 448, CIFAR-10 Batch 1:   cost_score 0.159994 accuracy_score 0.5482
# Epoch 449, CIFAR-10 Batch 1:   cost_score 0.157147 accuracy_score 0.5502
# Epoch 450, CIFAR-10 Batch 1:   cost_score 0.154314 accuracy_score 0.551
# Epoch 451, CIFAR-10 Batch 1:   cost_score 0.15132 accuracy_score 0.5518
# Epoch 452, CIFAR-10 Batch 1:   cost_score 0.151302 accuracy_score 0.5512
# Epoch 453, CIFAR-10 Batch 1:   cost_score 0.147545 accuracy_score 0.5518
# Epoch 454, CIFAR-10 Batch 1:   cost_score 0.150756 accuracy_score 0.5538
# Epoch 455, CIFAR-10 Batch 1:   cost_score 0.148697 accuracy_score 0.553
# Epoch 456, CIFAR-10 Batch 1:   cost_score 0.147118 accuracy_score 0.5478
# Epoch 457, CIFAR-10 Batch 1:   cost_score 0.15035 accuracy_score 0.5512
# Epoch 458, CIFAR-10 Batch 1:   cost_score 0.14753 accuracy_score 0.552
# Epoch 459, CIFAR-10 Batch 1:   cost_score 0.148064 accuracy_score 0.551
# Epoch 460, CIFAR-10 Batch 1:   cost_score 0.148659 accuracy_score 0.5512
# Epoch 461, CIFAR-10 Batch 1:   cost_score 0.146042 accuracy_score 0.5536
# Epoch 462, CIFAR-10 Batch 1:   cost_score 0.144837 accuracy_score 0.554
# Epoch 463, CIFAR-10 Batch 1:   cost_score 0.146602 accuracy_score 0.5502
# Epoch 464, CIFAR-10 Batch 1:   cost_score 0.141941 accuracy_score 0.55
# Epoch 465, CIFAR-10 Batch 1:   cost_score 0.142531 accuracy_score 0.5486
# Epoch 466, CIFAR-10 Batch 1:   cost_score 0.14613 accuracy_score 0.5518
# Epoch 467, CIFAR-10 Batch 1:   cost_score 0.143297 accuracy_score 0.5516
# Epoch 468, CIFAR-10 Batch 1:   cost_score 0.144591 accuracy_score 0.55
# Epoch 469, CIFAR-10 Batch 1:   cost_score 0.147284 accuracy_score 0.5498
# Epoch 470, CIFAR-10 Batch 1:   cost_score 0.141987 accuracy_score 0.5542
# Epoch 471, CIFAR-10 Batch 1:   cost_score 0.143735 accuracy_score 0.556
# Epoch 472, CIFAR-10 Batch 1:   cost_score 0.14397 accuracy_score 0.5576
# Epoch 473, CIFAR-10 Batch 1:   cost_score 0.141126 accuracy_score 0.5552
# Epoch 474, CIFAR-10 Batch 1:   cost_score 0.142259 accuracy_score 0.5546
# Epoch 475, CIFAR-10 Batch 1:   cost_score 0.139584 accuracy_score 0.5514
# Epoch 476, CIFAR-10 Batch 1:   cost_score 0.137601 accuracy_score 0.5494
# Epoch 477, CIFAR-10 Batch 1:   cost_score 0.139768 accuracy_score 0.5476
# Epoch 478, CIFAR-10 Batch 1:   cost_score 0.137193 accuracy_score 0.5536
# Epoch 479, CIFAR-10 Batch 1:   cost_score 0.135538 accuracy_score 0.5524
# Epoch 480, CIFAR-10 Batch 1:   cost_score 0.136025 accuracy_score 0.5546
# Epoch 481, CIFAR-10 Batch 1:   cost_score 0.132871 accuracy_score 0.5556
# Epoch 482, CIFAR-10 Batch 1:   cost_score 0.134314 accuracy_score 0.5512
# Epoch 483, CIFAR-10 Batch 1:   cost_score 0.13488 accuracy_score 0.553
# Epoch 484, CIFAR-10 Batch 1:   cost_score 0.132747 accuracy_score 0.5556
# Epoch 485, CIFAR-10 Batch 1:   cost_score 0.131363 accuracy_score 0.5536
# Epoch 486, CIFAR-10 Batch 1:   cost_score 0.132009 accuracy_score 0.5566
# Epoch 487, CIFAR-10 Batch 1:   cost_score 0.133581 accuracy_score 0.5556
# Epoch 488, CIFAR-10 Batch 1:   cost_score 0.130147 accuracy_score 0.553
# Epoch 489, CIFAR-10 Batch 1:   cost_score 0.131524 accuracy_score 0.553
# Epoch 490, CIFAR-10 Batch 1:   cost_score 0.128282 accuracy_score 0.5528
# Epoch 491, CIFAR-10 Batch 1:   cost_score 0.130735 accuracy_score 0.5528
# Epoch 492, CIFAR-10 Batch 1:   cost_score 0.129363 accuracy_score 0.5564
# Epoch 493, CIFAR-10 Batch 1:   cost_score 0.127656 accuracy_score 0.5548
# Epoch 494, CIFAR-10 Batch 1:   cost_score 0.130438 accuracy_score 0.552
# Epoch 495, CIFAR-10 Batch 1:   cost_score 0.125254 accuracy_score 0.5558
# Epoch 496, CIFAR-10 Batch 1:   cost_score 0.126083 accuracy_score 0.5558
# Epoch 497, CIFAR-10 Batch 1:   cost_score 0.126338 accuracy_score 0.5538
# Epoch 498, CIFAR-10 Batch 1:   cost_score 0.125852 accuracy_score 0.5558
# Epoch 499, CIFAR-10 Batch 1:   cost_score 0.127806 accuracy_score 0.5552
# Epoch 500, CIFAR-10 Batch 1:   cost_score 0.124289 accuracy_score 0.5552

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:   cost_score 2.29866 accuracy_score 0.0974
# Epoch  1, CIFAR-10 Batch 2:   cost_score 2.29991 accuracy_score 0.1266
# Epoch  1, CIFAR-10 Batch 3:   cost_score 2.29409 accuracy_score 0.1216
# Epoch  1, CIFAR-10 Batch 4:   cost_score 2.29412 accuracy_score 0.1192
# Epoch  1, CIFAR-10 Batch 5:   cost_score 2.29236 accuracy_score 0.1178
# Epoch  2, CIFAR-10 Batch 1:   cost_score 2.28694 accuracy_score 0.1324
# Epoch  2, CIFAR-10 Batch 2:   cost_score 2.28562 accuracy_score 0.129
# Epoch  2, CIFAR-10 Batch 3:   cost_score 2.27616 accuracy_score 0.1268
# Epoch  2, CIFAR-10 Batch 4:   cost_score 2.26445 accuracy_score 0.1348
# Epoch  2, CIFAR-10 Batch 5:   cost_score 2.25182 accuracy_score 0.1472
# Epoch  3, CIFAR-10 Batch 1:   cost_score 2.23777 accuracy_score 0.163
# Epoch  3, CIFAR-10 Batch 2:   cost_score 2.21363 accuracy_score 0.1916
# Epoch  3, CIFAR-10 Batch 3:   cost_score 2.182 accuracy_score 0.2318
# Epoch  3, CIFAR-10 Batch 4:   cost_score 2.14105 accuracy_score 0.2242
# Epoch  3, CIFAR-10 Batch 5:   cost_score 2.11274 accuracy_score 0.2242
# Epoch  4, CIFAR-10 Batch 1:   cost_score 2.10548 accuracy_score 0.2262
# Epoch  4, CIFAR-10 Batch 2:   cost_score 2.05886 accuracy_score 0.274
# Epoch  4, CIFAR-10 Batch 3:   cost_score 2.01119 accuracy_score 0.3042
# Epoch  4, CIFAR-10 Batch 4:   cost_score 1.99244 accuracy_score 0.278
# Epoch  4, CIFAR-10 Batch 5:   cost_score 1.98248 accuracy_score 0.283
# Epoch  5, CIFAR-10 Batch 1:   cost_score 1.9833 accuracy_score 0.3102
# Epoch  5, CIFAR-10 Batch 2:   cost_score 1.95112 accuracy_score 0.3196
# Epoch  5, CIFAR-10 Batch 3:   cost_score 1.91765 accuracy_score 0.3186
# Epoch  5, CIFAR-10 Batch 4:   cost_score 1.90985 accuracy_score 0.3128
# Epoch  5, CIFAR-10 Batch 5:   cost_score 1.91358 accuracy_score 0.3296
# Epoch  6, CIFAR-10 Batch 1:   cost_score 1.92216 accuracy_score 0.3302
# Epoch  6, CIFAR-10 Batch 2:   cost_score 1.89532 accuracy_score 0.332
# Epoch  6, CIFAR-10 Batch 3:   cost_score 1.84573 accuracy_score 0.34
# Epoch  6, CIFAR-10 Batch 4:   cost_score 1.85163 accuracy_score 0.331
# Epoch  6, CIFAR-10 Batch 5:   cost_score 1.85172 accuracy_score 0.3404
# Epoch  7, CIFAR-10 Batch 1:   cost_score 1.85697 accuracy_score 0.3472
# Epoch  7, CIFAR-10 Batch 2:   cost_score 1.8335 accuracy_score 0.3424
# Epoch  7, CIFAR-10 Batch 3:   cost_score 1.80093 accuracy_score 0.354
# Epoch  7, CIFAR-10 Batch 4:   cost_score 1.79637 accuracy_score 0.3608
# Epoch  7, CIFAR-10 Batch 5:   cost_score 1.81114 accuracy_score 0.352
# Epoch  8, CIFAR-10 Batch 1:   cost_score 1.81049 accuracy_score 0.3612
# Epoch  8, CIFAR-10 Batch 2:   cost_score 1.79121 accuracy_score 0.373
# Epoch  8, CIFAR-10 Batch 3:   cost_score 1.76978 accuracy_score 0.3642
# Epoch  8, CIFAR-10 Batch 4:   cost_score 1.75829 accuracy_score 0.3702
# Epoch  8, CIFAR-10 Batch 5:   cost_score 1.76447 accuracy_score 0.3714
# Epoch  9, CIFAR-10 Batch 1:   cost_score 1.78074 accuracy_score 0.3678
# Epoch  9, CIFAR-10 Batch 2:   cost_score 1.75028 accuracy_score 0.3812
# Epoch  9, CIFAR-10 Batch 3:   cost_score 1.71623 accuracy_score 0.38
# Epoch  9, CIFAR-10 Batch 4:   cost_score 1.7252 accuracy_score 0.374
# Epoch  9, CIFAR-10 Batch 5:   cost_score 1.7241 accuracy_score 0.377
# Epoch 10, CIFAR-10 Batch 1:   cost_score 1.74149 accuracy_score 0.3758
# Epoch 10, CIFAR-10 Batch 2:   cost_score 1.71618 accuracy_score 0.3868
# Epoch 10, CIFAR-10 Batch 3:   cost_score 1.68458 accuracy_score 0.3842
# Epoch 10, CIFAR-10 Batch 4:   cost_score 1.70199 accuracy_score 0.3824
# Epoch 10, CIFAR-10 Batch 5:   cost_score 1.6974 accuracy_score 0.385
# Epoch 11, CIFAR-10 Batch 1:   cost_score 1.72686 accuracy_score 0.3816
# Epoch 11, CIFAR-10 Batch 2:   cost_score 1.69813 accuracy_score 0.3956
# Epoch 11, CIFAR-10 Batch 3:   cost_score 1.66261 accuracy_score 0.3946
# Epoch 11, CIFAR-10 Batch 4:   cost_score 1.68665 accuracy_score 0.3878
# Epoch 11, CIFAR-10 Batch 5:   cost_score 1.6691 accuracy_score 0.3918
# Epoch 12, CIFAR-10 Batch 1:   cost_score 1.71189 accuracy_score 0.3896
# Epoch 12, CIFAR-10 Batch 2:   cost_score 1.68692 accuracy_score 0.4054
# Epoch 12, CIFAR-10 Batch 3:   cost_score 1.62146 accuracy_score 0.3998
# Epoch 12, CIFAR-10 Batch 4:   cost_score 1.68649 accuracy_score 0.3892
# Epoch 12, CIFAR-10 Batch 5:   cost_score 1.66192 accuracy_score 0.3992
# Epoch 13, CIFAR-10 Batch 1:   cost_score 1.65342 accuracy_score 0.4042
# Epoch 13, CIFAR-10 Batch 2:   cost_score 1.69927 accuracy_score 0.4024
# Epoch 13, CIFAR-10 Batch 3:   cost_score 1.60757 accuracy_score 0.409
# Epoch 13, CIFAR-10 Batch 4:   cost_score 1.63656 accuracy_score 0.4024
# Epoch 13, CIFAR-10 Batch 5:   cost_score 1.65029 accuracy_score 0.4018
# Epoch 14, CIFAR-10 Batch 1:   cost_score 1.62697 accuracy_score 0.4118
# Epoch 14, CIFAR-10 Batch 2:   cost_score 1.66649 accuracy_score 0.411
# Epoch 14, CIFAR-10 Batch 3:   cost_score 1.58941 accuracy_score 0.411
# Epoch 14, CIFAR-10 Batch 4:   cost_score 1.6087 accuracy_score 0.4074
# Epoch 14, CIFAR-10 Batch 5:   cost_score 1.61917 accuracy_score 0.4108
# Epoch 15, CIFAR-10 Batch 1:   cost_score 1.61004 accuracy_score 0.4144
# Epoch 15, CIFAR-10 Batch 2:   cost_score 1.6446 accuracy_score 0.4162
# Epoch 15, CIFAR-10 Batch 3:   cost_score 1.56966 accuracy_score 0.417
# Epoch 15, CIFAR-10 Batch 4:   cost_score 1.60711 accuracy_score 0.4054
# Epoch 15, CIFAR-10 Batch 5:   cost_score 1.5908 accuracy_score 0.4144
# Epoch 16, CIFAR-10 Batch 1:   cost_score 1.59626 accuracy_score 0.4172
# Epoch 16, CIFAR-10 Batch 2:   cost_score 1.62662 accuracy_score 0.4248
# Epoch 16, CIFAR-10 Batch 3:   cost_score 1.55244 accuracy_score 0.423
# Epoch 16, CIFAR-10 Batch 4:   cost_score 1.60284 accuracy_score 0.4124
# Epoch 16, CIFAR-10 Batch 5:   cost_score 1.57049 accuracy_score 0.4228
# Epoch 17, CIFAR-10 Batch 1:   cost_score 1.57285 accuracy_score 0.4252
# Epoch 17, CIFAR-10 Batch 2:   cost_score 1.63128 accuracy_score 0.4238
# Epoch 17, CIFAR-10 Batch 3:   cost_score 1.53509 accuracy_score 0.4268
# Epoch 17, CIFAR-10 Batch 4:   cost_score 1.57417 accuracy_score 0.4198
# Epoch 17, CIFAR-10 Batch 5:   cost_score 1.56288 accuracy_score 0.4224
# Epoch 18, CIFAR-10 Batch 1:   cost_score 1.54925 accuracy_score 0.4306
# Epoch 18, CIFAR-10 Batch 2:   cost_score 1.61919 accuracy_score 0.4252
# Epoch 18, CIFAR-10 Batch 3:   cost_score 1.51682 accuracy_score 0.4348
# Epoch 18, CIFAR-10 Batch 4:   cost_score 1.5426 accuracy_score 0.4258
# Epoch 18, CIFAR-10 Batch 5:   cost_score 1.55022 accuracy_score 0.4236
# Epoch 19, CIFAR-10 Batch 1:   cost_score 1.53361 accuracy_score 0.4352
# Epoch 19, CIFAR-10 Batch 2:   cost_score 1.59242 accuracy_score 0.4344
# Epoch 19, CIFAR-10 Batch 3:   cost_score 1.50945 accuracy_score 0.438
# Epoch 19, CIFAR-10 Batch 4:   cost_score 1.53031 accuracy_score 0.4324
# Epoch 19, CIFAR-10 Batch 5:   cost_score 1.52357 accuracy_score 0.4328
# Epoch 20, CIFAR-10 Batch 1:   cost_score 1.51905 accuracy_score 0.4364
# Epoch 20, CIFAR-10 Batch 2:   cost_score 1.57947 accuracy_score 0.4338
# Epoch 20, CIFAR-10 Batch 3:   cost_score 1.49271 accuracy_score 0.4386
# Epoch 20, CIFAR-10 Batch 4:   cost_score 1.52149 accuracy_score 0.4322
# Epoch 20, CIFAR-10 Batch 5:   cost_score 1.5094 accuracy_score 0.4342
# Epoch 21, CIFAR-10 Batch 1:   cost_score 1.51712 accuracy_score 0.435
# Epoch 21, CIFAR-10 Batch 2:   cost_score 1.56099 accuracy_score 0.444
# Epoch 21, CIFAR-10 Batch 3:   cost_score 1.48512 accuracy_score 0.4442
# Epoch 21, CIFAR-10 Batch 4:   cost_score 1.52019 accuracy_score 0.4312
# Epoch 21, CIFAR-10 Batch 5:   cost_score 1.49232 accuracy_score 0.4402
# Epoch 22, CIFAR-10 Batch 1:   cost_score 1.48685 accuracy_score 0.4442
# Epoch 22, CIFAR-10 Batch 2:   cost_score 1.55494 accuracy_score 0.4406
# Epoch 22, CIFAR-10 Batch 3:   cost_score 1.46421 accuracy_score 0.444
# Epoch 22, CIFAR-10 Batch 4:   cost_score 1.49741 accuracy_score 0.4378
# Epoch 22, CIFAR-10 Batch 5:   cost_score 1.47795 accuracy_score 0.446
# Epoch 23, CIFAR-10 Batch 1:   cost_score 1.47647 accuracy_score 0.4492
# Epoch 23, CIFAR-10 Batch 2:   cost_score 1.54588 accuracy_score 0.4466
# Epoch 23, CIFAR-10 Batch 3:   cost_score 1.4616 accuracy_score 0.4508
# Epoch 23, CIFAR-10 Batch 4:   cost_score 1.48659 accuracy_score 0.4436
# Epoch 23, CIFAR-10 Batch 5:   cost_score 1.47699 accuracy_score 0.4472
# Epoch 24, CIFAR-10 Batch 1:   cost_score 1.46933 accuracy_score 0.4496
# Epoch 24, CIFAR-10 Batch 2:   cost_score 1.53496 accuracy_score 0.4534
# Epoch 24, CIFAR-10 Batch 3:   cost_score 1.44445 accuracy_score 0.454
# Epoch 24, CIFAR-10 Batch 4:   cost_score 1.45988 accuracy_score 0.4516
# Epoch 24, CIFAR-10 Batch 5:   cost_score 1.45935 accuracy_score 0.4512
# Epoch 25, CIFAR-10 Batch 1:   cost_score 1.46118 accuracy_score 0.451
# Epoch 25, CIFAR-10 Batch 2:   cost_score 1.51016 accuracy_score 0.4582
# Epoch 25, CIFAR-10 Batch 3:   cost_score 1.43235 accuracy_score 0.4586
# Epoch 25, CIFAR-10 Batch 4:   cost_score 1.45478 accuracy_score 0.4524
# Epoch 25, CIFAR-10 Batch 5:   cost_score 1.43829 accuracy_score 0.4612
# Epoch 26, CIFAR-10 Batch 1:   cost_score 1.44805 accuracy_score 0.4554
# Epoch 26, CIFAR-10 Batch 2:   cost_score 1.49304 accuracy_score 0.4692
# Epoch 26, CIFAR-10 Batch 3:   cost_score 1.41673 accuracy_score 0.463
# Epoch 26, CIFAR-10 Batch 4:   cost_score 1.45182 accuracy_score 0.4486
# Epoch 26, CIFAR-10 Batch 5:   cost_score 1.42172 accuracy_score 0.4602
# Epoch 27, CIFAR-10 Batch 1:   cost_score 1.43897 accuracy_score 0.4554
# Epoch 27, CIFAR-10 Batch 2:   cost_score 1.48928 accuracy_score 0.463
# Epoch 27, CIFAR-10 Batch 3:   cost_score 1.39681 accuracy_score 0.4666
# Epoch 27, CIFAR-10 Batch 4:   cost_score 1.45018 accuracy_score 0.4502
# Epoch 27, CIFAR-10 Batch 5:   cost_score 1.40298 accuracy_score 0.4666
# Epoch 28, CIFAR-10 Batch 1:   cost_score 1.41527 accuracy_score 0.4656
# Epoch 28, CIFAR-10 Batch 2:   cost_score 1.48712 accuracy_score 0.4622
# Epoch 28, CIFAR-10 Batch 3:   cost_score 1.38382 accuracy_score 0.4722
# Epoch 28, CIFAR-10 Batch 4:   cost_score 1.41325 accuracy_score 0.4658
# Epoch 28, CIFAR-10 Batch 5:   cost_score 1.39607 accuracy_score 0.4682
# Epoch 29, CIFAR-10 Batch 1:   cost_score 1.40954 accuracy_score 0.4652
# Epoch 29, CIFAR-10 Batch 2:   cost_score 1.467 accuracy_score 0.4706
# Epoch 29, CIFAR-10 Batch 3:   cost_score 1.37715 accuracy_score 0.4722
# Epoch 29, CIFAR-10 Batch 4:   cost_score 1.40022 accuracy_score 0.4688
# Epoch 29, CIFAR-10 Batch 5:   cost_score 1.38891 accuracy_score 0.4676
# Epoch 30, CIFAR-10 Batch 1:   cost_score 1.38373 accuracy_score 0.4732
# Epoch 30, CIFAR-10 Batch 2:   cost_score 1.46159 accuracy_score 0.469
# Epoch 30, CIFAR-10 Batch 3:   cost_score 1.36486 accuracy_score 0.4716
# Epoch 30, CIFAR-10 Batch 4:   cost_score 1.39046 accuracy_score 0.4704
# Epoch 30, CIFAR-10 Batch 5:   cost_score 1.38196 accuracy_score 0.4694
# Epoch 31, CIFAR-10 Batch 1:   cost_score 1.37696 accuracy_score 0.4762
# Epoch 31, CIFAR-10 Batch 2:   cost_score 1.45619 accuracy_score 0.4702
# Epoch 31, CIFAR-10 Batch 3:   cost_score 1.36846 accuracy_score 0.4716
# Epoch 31, CIFAR-10 Batch 4:   cost_score 1.37596 accuracy_score 0.4734
# Epoch 31, CIFAR-10 Batch 5:   cost_score 1.36439 accuracy_score 0.4732
# Epoch 32, CIFAR-10 Batch 1:   cost_score 1.38477 accuracy_score 0.4742
# Epoch 32, CIFAR-10 Batch 2:   cost_score 1.43659 accuracy_score 0.478
# Epoch 32, CIFAR-10 Batch 3:   cost_score 1.35175 accuracy_score 0.479
# Epoch 32, CIFAR-10 Batch 4:   cost_score 1.37421 accuracy_score 0.4766
# Epoch 32, CIFAR-10 Batch 5:   cost_score 1.35805 accuracy_score 0.4732
# Epoch 33, CIFAR-10 Batch 1:   cost_score 1.36464 accuracy_score 0.4792
# Epoch 33, CIFAR-10 Batch 2:   cost_score 1.42409 accuracy_score 0.4844
# Epoch 33, CIFAR-10 Batch 3:   cost_score 1.33937 accuracy_score 0.4826
# Epoch 33, CIFAR-10 Batch 4:   cost_score 1.36751 accuracy_score 0.4768
# Epoch 33, CIFAR-10 Batch 5:   cost_score 1.35433 accuracy_score 0.4804
# Epoch 34, CIFAR-10 Batch 1:   cost_score 1.34544 accuracy_score 0.4866
# Epoch 34, CIFAR-10 Batch 2:   cost_score 1.42746 accuracy_score 0.4796
# Epoch 34, CIFAR-10 Batch 3:   cost_score 1.31816 accuracy_score 0.4902
# Epoch 34, CIFAR-10 Batch 4:   cost_score 1.35647 accuracy_score 0.4774
# Epoch 34, CIFAR-10 Batch 5:   cost_score 1.33858 accuracy_score 0.4834
# Epoch 35, CIFAR-10 Batch 1:   cost_score 1.32506 accuracy_score 0.492
# Epoch 35, CIFAR-10 Batch 2:   cost_score 1.41806 accuracy_score 0.481
# Epoch 35, CIFAR-10 Batch 3:   cost_score 1.29712 accuracy_score 0.4958
# Epoch 35, CIFAR-10 Batch 4:   cost_score 1.34721 accuracy_score 0.4804
# Epoch 35, CIFAR-10 Batch 5:   cost_score 1.32237 accuracy_score 0.4872
# Epoch 36, CIFAR-10 Batch 1:   cost_score 1.32819 accuracy_score 0.4954
# Epoch 36, CIFAR-10 Batch 2:   cost_score 1.39114 accuracy_score 0.4904
# Epoch 36, CIFAR-10 Batch 3:   cost_score 1.30447 accuracy_score 0.4904
# Epoch 36, CIFAR-10 Batch 4:   cost_score 1.33584 accuracy_score 0.4876
# Epoch 36, CIFAR-10 Batch 5:   cost_score 1.31457 accuracy_score 0.489
# Epoch 37, CIFAR-10 Batch 1:   cost_score 1.32148 accuracy_score 0.4918
# Epoch 37, CIFAR-10 Batch 2:   cost_score 1.37739 accuracy_score 0.4924
# Epoch 37, CIFAR-10 Batch 3:   cost_score 1.30141 accuracy_score 0.4952
# Epoch 37, CIFAR-10 Batch 4:   cost_score 1.30517 accuracy_score 0.495
# Epoch 37, CIFAR-10 Batch 5:   cost_score 1.31624 accuracy_score 0.489
# Epoch 38, CIFAR-10 Batch 1:   cost_score 1.29944 accuracy_score 0.4988
# Epoch 38, CIFAR-10 Batch 2:   cost_score 1.3918 accuracy_score 0.488
# Epoch 38, CIFAR-10 Batch 3:   cost_score 1.27908 accuracy_score 0.5024
# Epoch 38, CIFAR-10 Batch 4:   cost_score 1.31303 accuracy_score 0.4952
# Epoch 38, CIFAR-10 Batch 5:   cost_score 1.28821 accuracy_score 0.4998
# Epoch 39, CIFAR-10 Batch 1:   cost_score 1.29501 accuracy_score 0.502
# Epoch 39, CIFAR-10 Batch 2:   cost_score 1.37009 accuracy_score 0.4966
# Epoch 39, CIFAR-10 Batch 3:   cost_score 1.27068 accuracy_score 0.502
# Epoch 39, CIFAR-10 Batch 4:   cost_score 1.31172 accuracy_score 0.493
# Epoch 39, CIFAR-10 Batch 5:   cost_score 1.26854 accuracy_score 0.5056
# Epoch 40, CIFAR-10 Batch 1:   cost_score 1.27979 accuracy_score 0.508
# Epoch 40, CIFAR-10 Batch 2:   cost_score 1.36717 accuracy_score 0.4988
# Epoch 40, CIFAR-10 Batch 3:   cost_score 1.26409 accuracy_score 0.5052
# Epoch 40, CIFAR-10 Batch 4:   cost_score 1.29505 accuracy_score 0.505
# Epoch 40, CIFAR-10 Batch 5:   cost_score 1.27872 accuracy_score 0.5072
# Epoch 41, CIFAR-10 Batch 1:   cost_score 1.28334 accuracy_score 0.5076
# Epoch 41, CIFAR-10 Batch 2:   cost_score 1.36214 accuracy_score 0.4972
# Epoch 41, CIFAR-10 Batch 3:   cost_score 1.24409 accuracy_score 0.5124
# Epoch 41, CIFAR-10 Batch 4:   cost_score 1.29066 accuracy_score 0.4986
# Epoch 41, CIFAR-10 Batch 5:   cost_score 1.26396 accuracy_score 0.5032
# Epoch 42, CIFAR-10 Batch 1:   cost_score 1.28001 accuracy_score 0.5072
# Epoch 42, CIFAR-10 Batch 2:   cost_score 1.32145 accuracy_score 0.5118
# Epoch 42, CIFAR-10 Batch 3:   cost_score 1.2588 accuracy_score 0.5042
# Epoch 42, CIFAR-10 Batch 4:   cost_score 1.27145 accuracy_score 0.5068
# Epoch 42, CIFAR-10 Batch 5:   cost_score 1.24833 accuracy_score 0.5076
# Epoch 43, CIFAR-10 Batch 1:   cost_score 1.27852 accuracy_score 0.5062
# Epoch 43, CIFAR-10 Batch 2:   cost_score 1.31162 accuracy_score 0.5134
# Epoch 43, CIFAR-10 Batch 3:   cost_score 1.25427 accuracy_score 0.5082
# Epoch 43, CIFAR-10 Batch 4:   cost_score 1.25186 accuracy_score 0.5102
# Epoch 43, CIFAR-10 Batch 5:   cost_score 1.23838 accuracy_score 0.5096
# Epoch 44, CIFAR-10 Batch 1:   cost_score 1.25959 accuracy_score 0.5082
# Epoch 44, CIFAR-10 Batch 2:   cost_score 1.32083 accuracy_score 0.5082
# Epoch 44, CIFAR-10 Batch 3:   cost_score 1.22996 accuracy_score 0.5146
# Epoch 44, CIFAR-10 Batch 4:   cost_score 1.26523 accuracy_score 0.509
# Epoch 44, CIFAR-10 Batch 5:   cost_score 1.23728 accuracy_score 0.5124
# Epoch 45, CIFAR-10 Batch 1:   cost_score 1.23919 accuracy_score 0.5186
# Epoch 45, CIFAR-10 Batch 2:   cost_score 1.33981 accuracy_score 0.5018
# Epoch 45, CIFAR-10 Batch 3:   cost_score 1.21815 accuracy_score 0.5154
# Epoch 45, CIFAR-10 Batch 4:   cost_score 1.25256 accuracy_score 0.5134
# Epoch 45, CIFAR-10 Batch 5:   cost_score 1.24723 accuracy_score 0.51
# Epoch 46, CIFAR-10 Batch 1:   cost_score 1.23838 accuracy_score 0.5138
# Epoch 46, CIFAR-10 Batch 2:   cost_score 1.30362 accuracy_score 0.5072
# Epoch 46, CIFAR-10 Batch 3:   cost_score 1.22083 accuracy_score 0.5168
# Epoch 46, CIFAR-10 Batch 4:   cost_score 1.23558 accuracy_score 0.5168
# Epoch 46, CIFAR-10 Batch 5:   cost_score 1.22111 accuracy_score 0.5114
# Epoch 47, CIFAR-10 Batch 1:   cost_score 1.22801 accuracy_score 0.5188
# Epoch 47, CIFAR-10 Batch 2:   cost_score 1.2837 accuracy_score 0.5148
# Epoch 47, CIFAR-10 Batch 3:   cost_score 1.2138 accuracy_score 0.5228
# Epoch 47, CIFAR-10 Batch 4:   cost_score 1.24397 accuracy_score 0.5124
# Epoch 47, CIFAR-10 Batch 5:   cost_score 1.20111 accuracy_score 0.5206
# Epoch 48, CIFAR-10 Batch 1:   cost_score 1.22248 accuracy_score 0.5164
# Epoch 48, CIFAR-10 Batch 2:   cost_score 1.28402 accuracy_score 0.5174
# Epoch 48, CIFAR-10 Batch 3:   cost_score 1.18974 accuracy_score 0.5236
# Epoch 48, CIFAR-10 Batch 4:   cost_score 1.23916 accuracy_score 0.512
# Epoch 48, CIFAR-10 Batch 5:   cost_score 1.19916 accuracy_score 0.513
# Epoch 49, CIFAR-10 Batch 1:   cost_score 1.20515 accuracy_score 0.5238
# Epoch 49, CIFAR-10 Batch 2:   cost_score 1.28208 accuracy_score 0.517
# Epoch 49, CIFAR-10 Batch 3:   cost_score 1.19113 accuracy_score 0.5232
# Epoch 49, CIFAR-10 Batch 4:   cost_score 1.22269 accuracy_score 0.5188
# Epoch 49, CIFAR-10 Batch 5:   cost_score 1.19504 accuracy_score 0.5234
# Epoch 50, CIFAR-10 Batch 1:   cost_score 1.21179 accuracy_score 0.523
# Epoch 50, CIFAR-10 Batch 2:   cost_score 1.26635 accuracy_score 0.5228
# Epoch 50, CIFAR-10 Batch 3:   cost_score 1.18851 accuracy_score 0.5216
# Epoch 50, CIFAR-10 Batch 4:   cost_score 1.21213 accuracy_score 0.5234
# Epoch 50, CIFAR-10 Batch 5:   cost_score 1.1951 accuracy_score 0.5204
# Epoch 51, CIFAR-10 Batch 1:   cost_score 1.19325 accuracy_score 0.5264
# Epoch 51, CIFAR-10 Batch 2:   cost_score 1.27486 accuracy_score 0.5176
# Epoch 51, CIFAR-10 Batch 3:   cost_score 1.17443 accuracy_score 0.5284
# Epoch 51, CIFAR-10 Batch 4:   cost_score 1.19617 accuracy_score 0.5276
# Epoch 51, CIFAR-10 Batch 5:   cost_score 1.18694 accuracy_score 0.5196
# Epoch 52, CIFAR-10 Batch 1:   cost_score 1.19179 accuracy_score 0.525
# Epoch 52, CIFAR-10 Batch 2:   cost_score 1.2534 accuracy_score 0.5258
# Epoch 52, CIFAR-10 Batch 3:   cost_score 1.17067 accuracy_score 0.5258
# Epoch 52, CIFAR-10 Batch 4:   cost_score 1.2024 accuracy_score 0.5236
# Epoch 52, CIFAR-10 Batch 5:   cost_score 1.16981 accuracy_score 0.5258
# Epoch 53, CIFAR-10 Batch 1:   cost_score 1.17596 accuracy_score 0.5296
# Epoch 53, CIFAR-10 Batch 2:   cost_score 1.26049 accuracy_score 0.5204
# Epoch 53, CIFAR-10 Batch 3:   cost_score 1.17663 accuracy_score 0.521
# Epoch 53, CIFAR-10 Batch 4:   cost_score 1.18521 accuracy_score 0.5302
# Epoch 53, CIFAR-10 Batch 5:   cost_score 1.16042 accuracy_score 0.5328
# Epoch 54, CIFAR-10 Batch 1:   cost_score 1.17131 accuracy_score 0.53
# Epoch 54, CIFAR-10 Batch 2:   cost_score 1.25184 accuracy_score 0.5218
# Epoch 54, CIFAR-10 Batch 3:   cost_score 1.1528 accuracy_score 0.5294
# Epoch 54, CIFAR-10 Batch 4:   cost_score 1.16859 accuracy_score 0.534
# Epoch 54, CIFAR-10 Batch 5:   cost_score 1.17238 accuracy_score 0.5262
# Epoch 55, CIFAR-10 Batch 1:   cost_score 1.16031 accuracy_score 0.5334
# Epoch 55, CIFAR-10 Batch 2:   cost_score 1.23387 accuracy_score 0.5232
# Epoch 55, CIFAR-10 Batch 3:   cost_score 1.15348 accuracy_score 0.5306
# Epoch 55, CIFAR-10 Batch 4:   cost_score 1.16941 accuracy_score 0.5318
# Epoch 55, CIFAR-10 Batch 5:   cost_score 1.15309 accuracy_score 0.5296
# Epoch 56, CIFAR-10 Batch 1:   cost_score 1.15788 accuracy_score 0.535
# Epoch 56, CIFAR-10 Batch 2:   cost_score 1.23697 accuracy_score 0.523
# Epoch 56, CIFAR-10 Batch 3:   cost_score 1.13957 accuracy_score 0.5368
# Epoch 56, CIFAR-10 Batch 4:   cost_score 1.16732 accuracy_score 0.5344
# Epoch 56, CIFAR-10 Batch 5:   cost_score 1.14315 accuracy_score 0.5308
# Epoch 57, CIFAR-10 Batch 1:   cost_score 1.15742 accuracy_score 0.5324
# Epoch 57, CIFAR-10 Batch 2:   cost_score 1.21735 accuracy_score 0.53
# Epoch 57, CIFAR-10 Batch 3:   cost_score 1.13281 accuracy_score 0.5372
# Epoch 57, CIFAR-10 Batch 4:   cost_score 1.16861 accuracy_score 0.5304
# Epoch 57, CIFAR-10 Batch 5:   cost_score 1.13586 accuracy_score 0.5266
# Epoch 58, CIFAR-10 Batch 1:   cost_score 1.15008 accuracy_score 0.5314
# Epoch 58, CIFAR-10 Batch 2:   cost_score 1.22324 accuracy_score 0.5274
# Epoch 58, CIFAR-10 Batch 3:   cost_score 1.1302 accuracy_score 0.5376
# Epoch 58, CIFAR-10 Batch 4:   cost_score 1.15827 accuracy_score 0.529
# Epoch 58, CIFAR-10 Batch 5:   cost_score 1.14189 accuracy_score 0.529
# Epoch 59, CIFAR-10 Batch 1:   cost_score 1.13389 accuracy_score 0.5372
# Epoch 59, CIFAR-10 Batch 2:   cost_score 1.23007 accuracy_score 0.5238
# Epoch 59, CIFAR-10 Batch 3:   cost_score 1.12172 accuracy_score 0.5382
# Epoch 59, CIFAR-10 Batch 4:   cost_score 1.1506 accuracy_score 0.534
# Epoch 59, CIFAR-10 Batch 5:   cost_score 1.13392 accuracy_score 0.531
# Epoch 60, CIFAR-10 Batch 1:   cost_score 1.12829 accuracy_score 0.5384
# Epoch 60, CIFAR-10 Batch 2:   cost_score 1.20926 accuracy_score 0.5252
# Epoch 60, CIFAR-10 Batch 3:   cost_score 1.11428 accuracy_score 0.5384
# Epoch 60, CIFAR-10 Batch 4:   cost_score 1.14626 accuracy_score 0.534
# Epoch 60, CIFAR-10 Batch 5:   cost_score 1.10545 accuracy_score 0.539
# Epoch 61, CIFAR-10 Batch 1:   cost_score 1.1321 accuracy_score 0.536
# Epoch 61, CIFAR-10 Batch 2:   cost_score 1.1952 accuracy_score 0.5352
# Epoch 61, CIFAR-10 Batch 3:   cost_score 1.11525 accuracy_score 0.5412
# Epoch 61, CIFAR-10 Batch 4:   cost_score 1.13854 accuracy_score 0.5374
# Epoch 61, CIFAR-10 Batch 5:   cost_score 1.12414 accuracy_score 0.5318
# Epoch 62, CIFAR-10 Batch 1:   cost_score 1.11562 accuracy_score 0.5426
# Epoch 62, CIFAR-10 Batch 2:   cost_score 1.19844 accuracy_score 0.528
# Epoch 62, CIFAR-10 Batch 3:   cost_score 1.10931 accuracy_score 0.5376
# Epoch 62, CIFAR-10 Batch 4:   cost_score 1.12938 accuracy_score 0.54
# Epoch 62, CIFAR-10 Batch 5:   cost_score 1.1315 accuracy_score 0.5278
# Epoch 63, CIFAR-10 Batch 1:   cost_score 1.1085 accuracy_score 0.5424
# Epoch 63, CIFAR-10 Batch 2:   cost_score 1.21263 accuracy_score 0.5228
# Epoch 63, CIFAR-10 Batch 3:   cost_score 1.09611 accuracy_score 0.5428
# Epoch 63, CIFAR-10 Batch 4:   cost_score 1.11684 accuracy_score 0.5448
# Epoch 63, CIFAR-10 Batch 5:   cost_score 1.12815 accuracy_score 0.5264
# Epoch 64, CIFAR-10 Batch 1:   cost_score 1.09988 accuracy_score 0.5464
# Epoch 64, CIFAR-10 Batch 2:   cost_score 1.19868 accuracy_score 0.5252
# Epoch 64, CIFAR-10 Batch 3:   cost_score 1.0955 accuracy_score 0.5434
# Epoch 64, CIFAR-10 Batch 4:   cost_score 1.09258 accuracy_score 0.5506
# Epoch 64, CIFAR-10 Batch 5:   cost_score 1.13364 accuracy_score 0.5258
# Epoch 65, CIFAR-10 Batch 1:   cost_score 1.10081 accuracy_score 0.5418
# Epoch 65, CIFAR-10 Batch 2:   cost_score 1.17013 accuracy_score 0.5336
# Epoch 65, CIFAR-10 Batch 3:   cost_score 1.10348 accuracy_score 0.539
# Epoch 65, CIFAR-10 Batch 4:   cost_score 1.10231 accuracy_score 0.5478
# Epoch 65, CIFAR-10 Batch 5:   cost_score 1.10597 accuracy_score 0.5348
# Epoch 66, CIFAR-10 Batch 1:   cost_score 1.09812 accuracy_score 0.5428
# Epoch 66, CIFAR-10 Batch 2:   cost_score 1.1464 accuracy_score 0.5406
# Epoch 66, CIFAR-10 Batch 3:   cost_score 1.10988 accuracy_score 0.5326
# Epoch 66, CIFAR-10 Batch 4:   cost_score 1.10135 accuracy_score 0.5466
# Epoch 66, CIFAR-10 Batch 5:   cost_score 1.09679 accuracy_score 0.5372
# Epoch 67, CIFAR-10 Batch 1:   cost_score 1.10116 accuracy_score 0.542
# Epoch 67, CIFAR-10 Batch 2:   cost_score 1.1357 accuracy_score 0.543
# Epoch 67, CIFAR-10 Batch 3:   cost_score 1.10833 accuracy_score 0.5342
# Epoch 67, CIFAR-10 Batch 4:   cost_score 1.09579 accuracy_score 0.546
# Epoch 67, CIFAR-10 Batch 5:   cost_score 1.08014 accuracy_score 0.5446
# Epoch 68, CIFAR-10 Batch 1:   cost_score 1.11871 accuracy_score 0.538
# Epoch 68, CIFAR-10 Batch 2:   cost_score 1.12928 accuracy_score 0.5472
# Epoch 68, CIFAR-10 Batch 3:   cost_score 1.07949 accuracy_score 0.5424
# Epoch 68, CIFAR-10 Batch 4:   cost_score 1.09993 accuracy_score 0.545
# Epoch 68, CIFAR-10 Batch 5:   cost_score 1.06513 accuracy_score 0.5454
# Epoch 69, CIFAR-10 Batch 1:   cost_score 1.09178 accuracy_score 0.5408
# Epoch 69, CIFAR-10 Batch 2:   cost_score 1.13528 accuracy_score 0.5456
# Epoch 69, CIFAR-10 Batch 3:   cost_score 1.05844 accuracy_score 0.5496
# Epoch 69, CIFAR-10 Batch 4:   cost_score 1.09598 accuracy_score 0.5442
# Epoch 69, CIFAR-10 Batch 5:   cost_score 1.05991 accuracy_score 0.545
# Epoch 70, CIFAR-10 Batch 1:   cost_score 1.06993 accuracy_score 0.5502
# Epoch 70, CIFAR-10 Batch 2:   cost_score 1.13677 accuracy_score 0.5412
# Epoch 70, CIFAR-10 Batch 3:   cost_score 1.0571 accuracy_score 0.5464
# Epoch 70, CIFAR-10 Batch 4:   cost_score 1.08676 accuracy_score 0.548
# Epoch 70, CIFAR-10 Batch 5:   cost_score 1.07131 accuracy_score 0.5436
# Epoch 71, CIFAR-10 Batch 1:   cost_score 1.0829 accuracy_score 0.546
# Epoch 71, CIFAR-10 Batch 2:   cost_score 1.13874 accuracy_score 0.5444
# Epoch 71, CIFAR-10 Batch 3:   cost_score 1.07236 accuracy_score 0.548
# Epoch 71, CIFAR-10 Batch 4:   cost_score 1.06797 accuracy_score 0.5546
# Epoch 71, CIFAR-10 Batch 5:   cost_score 1.06302 accuracy_score 0.5444
# Epoch 72, CIFAR-10 Batch 1:   cost_score 1.07017 accuracy_score 0.5492
# Epoch 72, CIFAR-10 Batch 2:   cost_score 1.11628 accuracy_score 0.5488
# Epoch 72, CIFAR-10 Batch 3:   cost_score 1.05595 accuracy_score 0.5518
# Epoch 72, CIFAR-10 Batch 4:   cost_score 1.06542 accuracy_score 0.5576
# Epoch 72, CIFAR-10 Batch 5:   cost_score 1.04248 accuracy_score 0.553
# Epoch 73, CIFAR-10 Batch 1:   cost_score 1.06695 accuracy_score 0.5446
# Epoch 73, CIFAR-10 Batch 2:   cost_score 1.13243 accuracy_score 0.5436
# Epoch 73, CIFAR-10 Batch 3:   cost_score 1.03717 accuracy_score 0.5528
# Epoch 73, CIFAR-10 Batch 4:   cost_score 1.05196 accuracy_score 0.5564
# Epoch 73, CIFAR-10 Batch 5:   cost_score 1.05918 accuracy_score 0.547
# Epoch 74, CIFAR-10 Batch 1:   cost_score 1.05565 accuracy_score 0.5516
# Epoch 74, CIFAR-10 Batch 2:   cost_score 1.12064 accuracy_score 0.5436
# Epoch 74, CIFAR-10 Batch 3:   cost_score 1.04348 accuracy_score 0.5494
# Epoch 74, CIFAR-10 Batch 4:   cost_score 1.04927 accuracy_score 0.5568
# Epoch 74, CIFAR-10 Batch 5:   cost_score 1.06531 accuracy_score 0.5404
# Epoch 75, CIFAR-10 Batch 1:   cost_score 1.04743 accuracy_score 0.5528
# Epoch 75, CIFAR-10 Batch 2:   cost_score 1.1116 accuracy_score 0.545
# Epoch 75, CIFAR-10 Batch 3:   cost_score 1.0533 accuracy_score 0.5464
# Epoch 75, CIFAR-10 Batch 4:   cost_score 1.04351 accuracy_score 0.5598
# Epoch 75, CIFAR-10 Batch 5:   cost_score 1.06804 accuracy_score 0.5392
# Epoch 76, CIFAR-10 Batch 1:   cost_score 1.05387 accuracy_score 0.5526
# Epoch 76, CIFAR-10 Batch 2:   cost_score 1.09744 accuracy_score 0.5506
# Epoch 76, CIFAR-10 Batch 3:   cost_score 1.06135 accuracy_score 0.546
# Epoch 76, CIFAR-10 Batch 4:   cost_score 1.04362 accuracy_score 0.559
# Epoch 76, CIFAR-10 Batch 5:   cost_score 1.0377 accuracy_score 0.5486
# Epoch 77, CIFAR-10 Batch 1:   cost_score 1.06266 accuracy_score 0.5504
# Epoch 77, CIFAR-10 Batch 2:   cost_score 1.08569 accuracy_score 0.5506
# Epoch 77, CIFAR-10 Batch 3:   cost_score 1.05555 accuracy_score 0.5446
# Epoch 77, CIFAR-10 Batch 4:   cost_score 1.03246 accuracy_score 0.5604
# Epoch 77, CIFAR-10 Batch 5:   cost_score 1.01004 accuracy_score 0.5566
# Epoch 78, CIFAR-10 Batch 1:   cost_score 1.06799 accuracy_score 0.543
# Epoch 78, CIFAR-10 Batch 2:   cost_score 1.07472 accuracy_score 0.5498
# Epoch 78, CIFAR-10 Batch 3:   cost_score 1.02654 accuracy_score 0.5518
# Epoch 78, CIFAR-10 Batch 4:   cost_score 1.04585 accuracy_score 0.5534
# Epoch 78, CIFAR-10 Batch 5:   cost_score 1.01372 accuracy_score 0.5516
# Epoch 79, CIFAR-10 Batch 1:   cost_score 1.04102 accuracy_score 0.5526
# Epoch 79, CIFAR-10 Batch 2:   cost_score 1.08572 accuracy_score 0.5516
# Epoch 79, CIFAR-10 Batch 3:   cost_score 1.02419 accuracy_score 0.5536
# Epoch 79, CIFAR-10 Batch 4:   cost_score 1.05068 accuracy_score 0.5502
# Epoch 79, CIFAR-10 Batch 5:   cost_score 1.02043 accuracy_score 0.552
# Epoch 80, CIFAR-10 Batch 1:   cost_score 1.02781 accuracy_score 0.5524
# Epoch 80, CIFAR-10 Batch 2:   cost_score 1.08505 accuracy_score 0.5508
# Epoch 80, CIFAR-10 Batch 3:   cost_score 1.0173 accuracy_score 0.5546
# Epoch 80, CIFAR-10 Batch 4:   cost_score 1.02234 accuracy_score 0.559
# Epoch 80, CIFAR-10 Batch 5:   cost_score 1.03068 accuracy_score 0.5454
# Epoch 81, CIFAR-10 Batch 1:   cost_score 1.02367 accuracy_score 0.5592
# Epoch 81, CIFAR-10 Batch 2:   cost_score 1.07205 accuracy_score 0.552
# Epoch 81, CIFAR-10 Batch 3:   cost_score 1.01579 accuracy_score 0.552
# Epoch 81, CIFAR-10 Batch 4:   cost_score 1.01308 accuracy_score 0.5604
# Epoch 81, CIFAR-10 Batch 5:   cost_score 1.01763 accuracy_score 0.5486
# Epoch 82, CIFAR-10 Batch 1:   cost_score 1.02989 accuracy_score 0.5552
# Epoch 82, CIFAR-10 Batch 2:   cost_score 1.05616 accuracy_score 0.5606
# Epoch 82, CIFAR-10 Batch 3:   cost_score 1.01677 accuracy_score 0.5556
# Epoch 82, CIFAR-10 Batch 4:   cost_score 1.00442 accuracy_score 0.5652
# Epoch 82, CIFAR-10 Batch 5:   cost_score 1.00249 accuracy_score 0.5544
# Epoch 83, CIFAR-10 Batch 1:   cost_score 1.01981 accuracy_score 0.5562
# Epoch 83, CIFAR-10 Batch 2:   cost_score 1.04836 accuracy_score 0.5596
# Epoch 83, CIFAR-10 Batch 3:   cost_score 1.00844 accuracy_score 0.556
# Epoch 83, CIFAR-10 Batch 4:   cost_score 1.01133 accuracy_score 0.5584
# Epoch 83, CIFAR-10 Batch 5:   cost_score 0.990642 accuracy_score 0.5542
# Epoch 84, CIFAR-10 Batch 1:   cost_score 1.02447 accuracy_score 0.5524
# Epoch 84, CIFAR-10 Batch 2:   cost_score 1.05094 accuracy_score 0.5584
# Epoch 84, CIFAR-10 Batch 3:   cost_score 0.997158 accuracy_score 0.5552
# Epoch 84, CIFAR-10 Batch 4:   cost_score 1.01456 accuracy_score 0.5598
# Epoch 84, CIFAR-10 Batch 5:   cost_score 0.968391 accuracy_score 0.5626
# Epoch 85, CIFAR-10 Batch 1:   cost_score 1.01036 accuracy_score 0.5574
# Epoch 85, CIFAR-10 Batch 2:   cost_score 1.06577 accuracy_score 0.5548
# Epoch 85, CIFAR-10 Batch 3:   cost_score 0.983076 accuracy_score 0.56
# Epoch 85, CIFAR-10 Batch 4:   cost_score 1.00517 accuracy_score 0.5622
# Epoch 85, CIFAR-10 Batch 5:   cost_score 0.988367 accuracy_score 0.5562
# Epoch 86, CIFAR-10 Batch 1:   cost_score 1.00716 accuracy_score 0.5578
# Epoch 86, CIFAR-10 Batch 2:   cost_score 1.06016 accuracy_score 0.553
# Epoch 86, CIFAR-10 Batch 3:   cost_score 0.984433 accuracy_score 0.5622
# Epoch 86, CIFAR-10 Batch 4:   cost_score 0.995441 accuracy_score 0.5664
# Epoch 86, CIFAR-10 Batch 5:   cost_score 0.995604 accuracy_score 0.5556
# Epoch 87, CIFAR-10 Batch 1:   cost_score 1.00182 accuracy_score 0.5578
# Epoch 87, CIFAR-10 Batch 2:   cost_score 1.04525 accuracy_score 0.5576
# Epoch 87, CIFAR-10 Batch 3:   cost_score 0.985992 accuracy_score 0.5594
# Epoch 87, CIFAR-10 Batch 4:   cost_score 0.986723 accuracy_score 0.5644
# Epoch 87, CIFAR-10 Batch 5:   cost_score 0.978202 accuracy_score 0.5586
# Epoch 88, CIFAR-10 Batch 1:   cost_score 0.998597 accuracy_score 0.5596
# Epoch 88, CIFAR-10 Batch 2:   cost_score 1.03051 accuracy_score 0.5646
# Epoch 88, CIFAR-10 Batch 3:   cost_score 0.993077 accuracy_score 0.5574
# Epoch 88, CIFAR-10 Batch 4:   cost_score 0.993538 accuracy_score 0.5612
# Epoch 88, CIFAR-10 Batch 5:   cost_score 0.974866 accuracy_score 0.56
# Epoch 89, CIFAR-10 Batch 1:   cost_score 0.990884 accuracy_score 0.5622
# Epoch 89, CIFAR-10 Batch 2:   cost_score 1.01823 accuracy_score 0.5644
# Epoch 89, CIFAR-10 Batch 3:   cost_score 0.989656 accuracy_score 0.5566
# Epoch 89, CIFAR-10 Batch 4:   cost_score 0.986848 accuracy_score 0.5642
# Epoch 89, CIFAR-10 Batch 5:   cost_score 0.970574 accuracy_score 0.5592
# Epoch 90, CIFAR-10 Batch 1:   cost_score 0.987298 accuracy_score 0.5598
# Epoch 90, CIFAR-10 Batch 2:   cost_score 1.01143 accuracy_score 0.5654
# Epoch 90, CIFAR-10 Batch 3:   cost_score 0.971487 accuracy_score 0.5642
# Epoch 90, CIFAR-10 Batch 4:   cost_score 0.977115 accuracy_score 0.567
# Epoch 90, CIFAR-10 Batch 5:   cost_score 0.969425 accuracy_score 0.5582
# Epoch 91, CIFAR-10 Batch 1:   cost_score 0.983453 accuracy_score 0.5646
# Epoch 91, CIFAR-10 Batch 2:   cost_score 0.997094 accuracy_score 0.5706
# Epoch 91, CIFAR-10 Batch 3:   cost_score 0.972136 accuracy_score 0.562
# Epoch 91, CIFAR-10 Batch 4:   cost_score 0.981474 accuracy_score 0.5642
# Epoch 91, CIFAR-10 Batch 5:   cost_score 0.951449 accuracy_score 0.5604
# Epoch 92, CIFAR-10 Batch 1:   cost_score 0.989103 accuracy_score 0.5578
# Epoch 92, CIFAR-10 Batch 2:   cost_score 0.995025 accuracy_score 0.5696
# Epoch 92, CIFAR-10 Batch 3:   cost_score 0.962564 accuracy_score 0.5622
# Epoch 92, CIFAR-10 Batch 4:   cost_score 0.980316 accuracy_score 0.5628
# Epoch 92, CIFAR-10 Batch 5:   cost_score 0.954246 accuracy_score 0.562
# Epoch 93, CIFAR-10 Batch 1:   cost_score 0.983206 accuracy_score 0.5622
# Epoch 93, CIFAR-10 Batch 2:   cost_score 0.996152 accuracy_score 0.5676
# Epoch 93, CIFAR-10 Batch 3:   cost_score 0.957931 accuracy_score 0.5672
# Epoch 93, CIFAR-10 Batch 4:   cost_score 0.977203 accuracy_score 0.5646
# Epoch 93, CIFAR-10 Batch 5:   cost_score 0.945314 accuracy_score 0.564
# Epoch 94, CIFAR-10 Batch 1:   cost_score 0.970942 accuracy_score 0.5644
# Epoch 94, CIFAR-10 Batch 2:   cost_score 1.01904 accuracy_score 0.5622
# Epoch 94, CIFAR-10 Batch 3:   cost_score 0.951361 accuracy_score 0.5686
# Epoch 94, CIFAR-10 Batch 4:   cost_score 0.96583 accuracy_score 0.5652
# Epoch 94, CIFAR-10 Batch 5:   cost_score 0.946049 accuracy_score 0.5616
# Epoch 95, CIFAR-10 Batch 1:   cost_score 0.972821 accuracy_score 0.5644
# Epoch 95, CIFAR-10 Batch 2:   cost_score 1.00998 accuracy_score 0.564
# Epoch 95, CIFAR-10 Batch 3:   cost_score 0.941341 accuracy_score 0.5688
# Epoch 95, CIFAR-10 Batch 4:   cost_score 0.943989 accuracy_score 0.5698
# Epoch 95, CIFAR-10 Batch 5:   cost_score 0.948234 accuracy_score 0.5598
# Epoch 96, CIFAR-10 Batch 1:   cost_score 0.961658 accuracy_score 0.5654
# Epoch 96, CIFAR-10 Batch 2:   cost_score 0.998253 accuracy_score 0.57
# Epoch 96, CIFAR-10 Batch 3:   cost_score 0.950161 accuracy_score 0.5666
# Epoch 96, CIFAR-10 Batch 4:   cost_score 0.947093 accuracy_score 0.5698
# Epoch 96, CIFAR-10 Batch 5:   cost_score 0.94568 accuracy_score 0.562
# Epoch 97, CIFAR-10 Batch 1:   cost_score 0.95945 accuracy_score 0.5652
# Epoch 97, CIFAR-10 Batch 2:   cost_score 0.990447 accuracy_score 0.568
# Epoch 97, CIFAR-10 Batch 3:   cost_score 0.950184 accuracy_score 0.567
# Epoch 97, CIFAR-10 Batch 4:   cost_score 0.941594 accuracy_score 0.5716
# Epoch 97, CIFAR-10 Batch 5:   cost_score 0.940236 accuracy_score 0.5646
# Epoch 98, CIFAR-10 Batch 1:   cost_score 0.959546 accuracy_score 0.566
# Epoch 98, CIFAR-10 Batch 2:   cost_score 0.979087 accuracy_score 0.5726
# Epoch 98, CIFAR-10 Batch 3:   cost_score 0.941821 accuracy_score 0.5684
# Epoch 98, CIFAR-10 Batch 4:   cost_score 0.939182 accuracy_score 0.5716
# Epoch 98, CIFAR-10 Batch 5:   cost_score 0.949559 accuracy_score 0.5584
# Epoch 99, CIFAR-10 Batch 1:   cost_score 0.949306 accuracy_score 0.5684
# Epoch 99, CIFAR-10 Batch 2:   cost_score 0.96525 accuracy_score 0.5734
# Epoch 99, CIFAR-10 Batch 3:   cost_score 0.936137 accuracy_score 0.5648
# Epoch 99, CIFAR-10 Batch 4:   cost_score 0.934234 accuracy_score 0.5704
# Epoch 99, CIFAR-10 Batch 5:   cost_score 0.923999 accuracy_score 0.568
# Epoch 100, CIFAR-10 Batch 1:   cost_score 0.933937 accuracy_score 0.5716
# Epoch 100, CIFAR-10 Batch 2:   cost_score 0.971692 accuracy_score 0.573
# Epoch 100, CIFAR-10 Batch 3:   cost_score 0.945658 accuracy_score 0.5648
# Epoch 100, CIFAR-10 Batch 4:   cost_score 0.935252 accuracy_score 0.5704
# Epoch 100, CIFAR-10 Batch 5:   cost_score 0.90886 accuracy_score 0.5726
# Epoch 101, CIFAR-10 Batch 1:   cost_score 0.949323 accuracy_score 0.5684
# Epoch 101, CIFAR-10 Batch 2:   cost_score 0.974961 accuracy_score 0.5668
# Epoch 101, CIFAR-10 Batch 3:   cost_score 0.924824 accuracy_score 0.5688
# Epoch 101, CIFAR-10 Batch 4:   cost_score 0.938428 accuracy_score 0.568
# Epoch 101, CIFAR-10 Batch 5:   cost_score 0.901261 accuracy_score 0.5736
# Epoch 102, CIFAR-10 Batch 1:   cost_score 0.946747 accuracy_score 0.5696
# Epoch 102, CIFAR-10 Batch 2:   cost_score 0.958476 accuracy_score 0.5766
# Epoch 102, CIFAR-10 Batch 3:   cost_score 0.901161 accuracy_score 0.5772
# Epoch 102, CIFAR-10 Batch 4:   cost_score 0.933308 accuracy_score 0.5718
# Epoch 102, CIFAR-10 Batch 5:   cost_score 0.899841 accuracy_score 0.5726
# Epoch 103, CIFAR-10 Batch 1:   cost_score 0.930894 accuracy_score 0.573
# Epoch 103, CIFAR-10 Batch 2:   cost_score 0.969159 accuracy_score 0.5726
# Epoch 103, CIFAR-10 Batch 3:   cost_score 0.910724 accuracy_score 0.573
# Epoch 103, CIFAR-10 Batch 4:   cost_score 0.933136 accuracy_score 0.5674
# Epoch 103, CIFAR-10 Batch 5:   cost_score 0.920741 accuracy_score 0.5652
# Epoch 104, CIFAR-10 Batch 1:   cost_score 0.917945 accuracy_score 0.576
# Epoch 104, CIFAR-10 Batch 2:   cost_score 0.972697 accuracy_score 0.5712
# Epoch 104, CIFAR-10 Batch 3:   cost_score 0.913056 accuracy_score 0.5734
# Epoch 104, CIFAR-10 Batch 4:   cost_score 0.907529 accuracy_score 0.5754
# Epoch 104, CIFAR-10 Batch 5:   cost_score 0.92166 accuracy_score 0.564
# Epoch 105, CIFAR-10 Batch 1:   cost_score 0.919035 accuracy_score 0.5724
# Epoch 105, CIFAR-10 Batch 2:   cost_score 0.969338 accuracy_score 0.5676
# Epoch 105, CIFAR-10 Batch 3:   cost_score 0.92444 accuracy_score 0.5684
# Epoch 105, CIFAR-10 Batch 4:   cost_score 0.895596 accuracy_score 0.5818
# Epoch 105, CIFAR-10 Batch 5:   cost_score 0.91977 accuracy_score 0.5628
# Epoch 106, CIFAR-10 Batch 1:   cost_score 0.926122 accuracy_score 0.5718
# Epoch 106, CIFAR-10 Batch 2:   cost_score 0.939326 accuracy_score 0.575
# Epoch 106, CIFAR-10 Batch 3:   cost_score 0.926146 accuracy_score 0.565
# Epoch 106, CIFAR-10 Batch 4:   cost_score 0.908713 accuracy_score 0.5748
# Epoch 106, CIFAR-10 Batch 5:   cost_score 0.896636 accuracy_score 0.5676
# Epoch 107, CIFAR-10 Batch 1:   cost_score 0.939841 accuracy_score 0.567
# Epoch 107, CIFAR-10 Batch 2:   cost_score 0.925913 accuracy_score 0.581
# Epoch 107, CIFAR-10 Batch 3:   cost_score 0.897509 accuracy_score 0.5736
# Epoch 107, CIFAR-10 Batch 4:   cost_score 0.931135 accuracy_score 0.567
# Epoch 107, CIFAR-10 Batch 5:   cost_score 0.875793 accuracy_score 0.5746
# Epoch 108, CIFAR-10 Batch 1:   cost_score 0.929719 accuracy_score 0.5698
# Epoch 108, CIFAR-10 Batch 2:   cost_score 0.946597 accuracy_score 0.5738
# Epoch 108, CIFAR-10 Batch 3:   cost_score 0.885253 accuracy_score 0.5746
# Epoch 108, CIFAR-10 Batch 4:   cost_score 0.913618 accuracy_score 0.5704
# Epoch 108, CIFAR-10 Batch 5:   cost_score 0.870109 accuracy_score 0.5734
# Epoch 109, CIFAR-10 Batch 1:   cost_score 0.914299 accuracy_score 0.5712
# Epoch 109, CIFAR-10 Batch 2:   cost_score 0.940672 accuracy_score 0.5748
# Epoch 109, CIFAR-10 Batch 3:   cost_score 0.887607 accuracy_score 0.5764
# Epoch 109, CIFAR-10 Batch 4:   cost_score 0.908874 accuracy_score 0.5694
# Epoch 109, CIFAR-10 Batch 5:   cost_score 0.867076 accuracy_score 0.577
# Epoch 110, CIFAR-10 Batch 1:   cost_score 0.902924 accuracy_score 0.576
# Epoch 110, CIFAR-10 Batch 2:   cost_score 0.940803 accuracy_score 0.575
# Epoch 110, CIFAR-10 Batch 3:   cost_score 0.874004 accuracy_score 0.5794
# Epoch 110, CIFAR-10 Batch 4:   cost_score 0.895119 accuracy_score 0.5732
# Epoch 110, CIFAR-10 Batch 5:   cost_score 0.8755 accuracy_score 0.5744
# Epoch 111, CIFAR-10 Batch 1:   cost_score 0.888228 accuracy_score 0.5768
# Epoch 111, CIFAR-10 Batch 2:   cost_score 0.960617 accuracy_score 0.5652
# Epoch 111, CIFAR-10 Batch 3:   cost_score 0.879504 accuracy_score 0.5756
# Epoch 111, CIFAR-10 Batch 4:   cost_score 0.887468 accuracy_score 0.5746
# Epoch 111, CIFAR-10 Batch 5:   cost_score 0.884317 accuracy_score 0.5682
# Epoch 112, CIFAR-10 Batch 1:   cost_score 0.882049 accuracy_score 0.5782
# Epoch 112, CIFAR-10 Batch 2:   cost_score 0.927291 accuracy_score 0.5762
# Epoch 112, CIFAR-10 Batch 3:   cost_score 0.888992 accuracy_score 0.572
# Epoch 112, CIFAR-10 Batch 4:   cost_score 0.891392 accuracy_score 0.5746
# Epoch 112, CIFAR-10 Batch 5:   cost_score 0.872983 accuracy_score 0.5704
# Epoch 113, CIFAR-10 Batch 1:   cost_score 0.888045 accuracy_score 0.58
# Epoch 113, CIFAR-10 Batch 2:   cost_score 0.920661 accuracy_score 0.576
# Epoch 113, CIFAR-10 Batch 3:   cost_score 0.874799 accuracy_score 0.5738
# Epoch 113, CIFAR-10 Batch 4:   cost_score 0.871787 accuracy_score 0.5816
# Epoch 113, CIFAR-10 Batch 5:   cost_score 0.870038 accuracy_score 0.5738
# Epoch 114, CIFAR-10 Batch 1:   cost_score 0.885114 accuracy_score 0.5816
# Epoch 114, CIFAR-10 Batch 2:   cost_score 0.924471 accuracy_score 0.5732
# Epoch 114, CIFAR-10 Batch 3:   cost_score 0.878352 accuracy_score 0.5738
# Epoch 114, CIFAR-10 Batch 4:   cost_score 0.865888 accuracy_score 0.5798
# Epoch 114, CIFAR-10 Batch 5:   cost_score 0.860174 accuracy_score 0.5746
# Epoch 115, CIFAR-10 Batch 1:   cost_score 0.898132 accuracy_score 0.5766
# Epoch 115, CIFAR-10 Batch 2:   cost_score 0.900373 accuracy_score 0.5822
# Epoch 115, CIFAR-10 Batch 3:   cost_score 0.875841 accuracy_score 0.5726
# Epoch 115, CIFAR-10 Batch 4:   cost_score 0.859958 accuracy_score 0.5798
# Epoch 115, CIFAR-10 Batch 5:   cost_score 0.848401 accuracy_score 0.5716
# Epoch 116, CIFAR-10 Batch 1:   cost_score 0.892174 accuracy_score 0.5714
# Epoch 116, CIFAR-10 Batch 2:   cost_score 0.887194 accuracy_score 0.5798
# Epoch 116, CIFAR-10 Batch 3:   cost_score 0.85807 accuracy_score 0.5784
# Epoch 116, CIFAR-10 Batch 4:   cost_score 0.886684 accuracy_score 0.573
# Epoch 116, CIFAR-10 Batch 5:   cost_score 0.81811 accuracy_score 0.5836
# Epoch 117, CIFAR-10 Batch 1:   cost_score 0.872507 accuracy_score 0.5768
# Epoch 117, CIFAR-10 Batch 2:   cost_score 0.909979 accuracy_score 0.5734
# Epoch 117, CIFAR-10 Batch 3:   cost_score 0.858121 accuracy_score 0.5764
# Epoch 117, CIFAR-10 Batch 4:   cost_score 0.869729 accuracy_score 0.5752
# Epoch 117, CIFAR-10 Batch 5:   cost_score 0.829019 accuracy_score 0.5772
# Epoch 118, CIFAR-10 Batch 1:   cost_score 0.875884 accuracy_score 0.5772
# Epoch 118, CIFAR-10 Batch 2:   cost_score 0.892821 accuracy_score 0.5812
# Epoch 118, CIFAR-10 Batch 3:   cost_score 0.851939 accuracy_score 0.5808
# Epoch 118, CIFAR-10 Batch 4:   cost_score 0.862403 accuracy_score 0.5814
# Epoch 118, CIFAR-10 Batch 5:   cost_score 0.84204 accuracy_score 0.5754
# Epoch 119, CIFAR-10 Batch 1:   cost_score 0.866054 accuracy_score 0.5774
# Epoch 119, CIFAR-10 Batch 2:   cost_score 0.887205 accuracy_score 0.5794
# Epoch 119, CIFAR-10 Batch 3:   cost_score 0.842652 accuracy_score 0.5786
# Epoch 119, CIFAR-10 Batch 4:   cost_score 0.846912 accuracy_score 0.5826
# Epoch 119, CIFAR-10 Batch 5:   cost_score 0.838869 accuracy_score 0.5752
# Epoch 120, CIFAR-10 Batch 1:   cost_score 0.866441 accuracy_score 0.5786
# Epoch 120, CIFAR-10 Batch 2:   cost_score 0.886363 accuracy_score 0.5834
# Epoch 120, CIFAR-10 Batch 3:   cost_score 0.84694 accuracy_score 0.5798
# Epoch 120, CIFAR-10 Batch 4:   cost_score 0.851093 accuracy_score 0.5828
# Epoch 120, CIFAR-10 Batch 5:   cost_score 0.821581 accuracy_score 0.5798
# Epoch 121, CIFAR-10 Batch 1:   cost_score 0.85616 accuracy_score 0.5824
# Epoch 121, CIFAR-10 Batch 2:   cost_score 0.891293 accuracy_score 0.5756
# Epoch 121, CIFAR-10 Batch 3:   cost_score 0.845647 accuracy_score 0.5756
# Epoch 121, CIFAR-10 Batch 4:   cost_score 0.837846 accuracy_score 0.584
# Epoch 121, CIFAR-10 Batch 5:   cost_score 0.840658 accuracy_score 0.578
# Epoch 122, CIFAR-10 Batch 1:   cost_score 0.855849 accuracy_score 0.5834
# Epoch 122, CIFAR-10 Batch 2:   cost_score 0.88302 accuracy_score 0.5812
# Epoch 122, CIFAR-10 Batch 3:   cost_score 0.840312 accuracy_score 0.5798
# Epoch 122, CIFAR-10 Batch 4:   cost_score 0.829262 accuracy_score 0.586
# Epoch 122, CIFAR-10 Batch 5:   cost_score 0.831811 accuracy_score 0.5788
# Epoch 123, CIFAR-10 Batch 1:   cost_score 0.847476 accuracy_score 0.5806
# Epoch 123, CIFAR-10 Batch 2:   cost_score 0.876577 accuracy_score 0.585
# Epoch 123, CIFAR-10 Batch 3:   cost_score 0.846671 accuracy_score 0.5838
# Epoch 123, CIFAR-10 Batch 4:   cost_score 0.82195 accuracy_score 0.5898
# Epoch 123, CIFAR-10 Batch 5:   cost_score 0.836304 accuracy_score 0.576
# Epoch 124, CIFAR-10 Batch 1:   cost_score 0.857692 accuracy_score 0.583
# Epoch 124, CIFAR-10 Batch 2:   cost_score 0.86718 accuracy_score 0.5868
# Epoch 124, CIFAR-10 Batch 3:   cost_score 0.850906 accuracy_score 0.5778
# Epoch 124, CIFAR-10 Batch 4:   cost_score 0.825763 accuracy_score 0.589
# Epoch 124, CIFAR-10 Batch 5:   cost_score 0.826472 accuracy_score 0.5788
# Epoch 125, CIFAR-10 Batch 1:   cost_score 0.854568 accuracy_score 0.5816
# Epoch 125, CIFAR-10 Batch 2:   cost_score 0.871171 accuracy_score 0.586
# Epoch 125, CIFAR-10 Batch 3:   cost_score 0.834972 accuracy_score 0.5824
# Epoch 125, CIFAR-10 Batch 4:   cost_score 0.815407 accuracy_score 0.586
# Epoch 125, CIFAR-10 Batch 5:   cost_score 0.83869 accuracy_score 0.5702
# Epoch 126, CIFAR-10 Batch 1:   cost_score 0.846996 accuracy_score 0.5806
# Epoch 126, CIFAR-10 Batch 2:   cost_score 0.84816 accuracy_score 0.5856
# Epoch 126, CIFAR-10 Batch 3:   cost_score 0.847944 accuracy_score 0.576
# Epoch 126, CIFAR-10 Batch 4:   cost_score 0.822262 accuracy_score 0.587
# Epoch 126, CIFAR-10 Batch 5:   cost_score 0.813709 accuracy_score 0.5786
# Epoch 127, CIFAR-10 Batch 1:   cost_score 0.866966 accuracy_score 0.578
# Epoch 127, CIFAR-10 Batch 2:   cost_score 0.834964 accuracy_score 0.5894
# Epoch 127, CIFAR-10 Batch 3:   cost_score 0.834282 accuracy_score 0.5806
# Epoch 127, CIFAR-10 Batch 4:   cost_score 0.817733 accuracy_score 0.5872
# Epoch 127, CIFAR-10 Batch 5:   cost_score 0.795793 accuracy_score 0.585
# Epoch 128, CIFAR-10 Batch 1:   cost_score 0.860578 accuracy_score 0.5746
# Epoch 128, CIFAR-10 Batch 2:   cost_score 0.845946 accuracy_score 0.5866
# Epoch 128, CIFAR-10 Batch 3:   cost_score 0.814895 accuracy_score 0.5854
# Epoch 128, CIFAR-10 Batch 4:   cost_score 0.822509 accuracy_score 0.5848
# Epoch 128, CIFAR-10 Batch 5:   cost_score 0.791335 accuracy_score 0.585
# Epoch 129, CIFAR-10 Batch 1:   cost_score 0.836254 accuracy_score 0.579
# Epoch 129, CIFAR-10 Batch 2:   cost_score 0.84461 accuracy_score 0.5834
# Epoch 129, CIFAR-10 Batch 3:   cost_score 0.804332 accuracy_score 0.584
# Epoch 129, CIFAR-10 Batch 4:   cost_score 0.818768 accuracy_score 0.5824
# Epoch 129, CIFAR-10 Batch 5:   cost_score 0.805633 accuracy_score 0.5794
# Epoch 130, CIFAR-10 Batch 1:   cost_score 0.838063 accuracy_score 0.5808
# Epoch 130, CIFAR-10 Batch 2:   cost_score 0.843227 accuracy_score 0.5862
# Epoch 130, CIFAR-10 Batch 3:   cost_score 0.805701 accuracy_score 0.5856
# Epoch 130, CIFAR-10 Batch 4:   cost_score 0.81593 accuracy_score 0.5828
# Epoch 130, CIFAR-10 Batch 5:   cost_score 0.787769 accuracy_score 0.5844
# Epoch 131, CIFAR-10 Batch 1:   cost_score 0.831032 accuracy_score 0.581
# Epoch 131, CIFAR-10 Batch 2:   cost_score 0.842444 accuracy_score 0.5834
# Epoch 131, CIFAR-10 Batch 3:   cost_score 0.80692 accuracy_score 0.5824
# Epoch 131, CIFAR-10 Batch 4:   cost_score 0.811457 accuracy_score 0.584
# Epoch 131, CIFAR-10 Batch 5:   cost_score 0.782435 accuracy_score 0.5882
# Epoch 132, CIFAR-10 Batch 1:   cost_score 0.823294 accuracy_score 0.5856
# Epoch 132, CIFAR-10 Batch 2:   cost_score 0.83402 accuracy_score 0.5868
# Epoch 132, CIFAR-10 Batch 3:   cost_score 0.818238 accuracy_score 0.581
# Epoch 132, CIFAR-10 Batch 4:   cost_score 0.805042 accuracy_score 0.5862
# Epoch 132, CIFAR-10 Batch 5:   cost_score 0.78719 accuracy_score 0.5822
# Epoch 133, CIFAR-10 Batch 1:   cost_score 0.83819 accuracy_score 0.582
# Epoch 133, CIFAR-10 Batch 2:   cost_score 0.825209 accuracy_score 0.5906
# Epoch 133, CIFAR-10 Batch 3:   cost_score 0.813405 accuracy_score 0.5856
# Epoch 133, CIFAR-10 Batch 4:   cost_score 0.798932 accuracy_score 0.5862
# Epoch 133, CIFAR-10 Batch 5:   cost_score 0.779419 accuracy_score 0.5862
# Epoch 134, CIFAR-10 Batch 1:   cost_score 0.849698 accuracy_score 0.5764
# Epoch 134, CIFAR-10 Batch 2:   cost_score 0.828505 accuracy_score 0.5874
# Epoch 134, CIFAR-10 Batch 3:   cost_score 0.787342 accuracy_score 0.588
# Epoch 134, CIFAR-10 Batch 4:   cost_score 0.810919 accuracy_score 0.5816
# Epoch 134, CIFAR-10 Batch 5:   cost_score 0.794365 accuracy_score 0.5752
# Epoch 135, CIFAR-10 Batch 1:   cost_score 0.809518 accuracy_score 0.5838
# Epoch 135, CIFAR-10 Batch 2:   cost_score 0.822534 accuracy_score 0.5894
# ...
# Epoch 457, CIFAR-10 Batch 1:   cost_score 0.324744 accuracy_score 0.6258
# Epoch 457, CIFAR-10 Batch 2:   cost_score 0.33117 accuracy_score 0.6234
# Epoch 457, CIFAR-10 Batch 3:   cost_score 0.307619 accuracy_score 0.6286
# Epoch 457, CIFAR-10 Batch 4:   cost_score 0.288556 accuracy_score 0.6302
# Epoch 457, CIFAR-10 Batch 5:   cost_score 0.288843 accuracy_score 0.6238
# Epoch 458, CIFAR-10 Batch 1:   cost_score 0.320209 accuracy_score 0.6228
# Epoch 458, CIFAR-10 Batch 2:   cost_score 0.325888 accuracy_score 0.626
# Epoch 458, CIFAR-10 Batch 3:   cost_score 0.3219 accuracy_score 0.624
# Epoch 458, CIFAR-10 Batch 4:   cost_score 0.303663 accuracy_score 0.6286
# Epoch 458, CIFAR-10 Batch 5:   cost_score 0.297418 accuracy_score 0.6258
# Epoch 459, CIFAR-10 Batch 1:   cost_score 0.315117 accuracy_score 0.628
# Epoch 459, CIFAR-10 Batch 2:   cost_score 0.31649 accuracy_score 0.6306
# Epoch 459, CIFAR-10 Batch 3:   cost_score 0.325301 accuracy_score 0.6274
# Epoch 459, CIFAR-10 Batch 4:   cost_score 0.309564 accuracy_score 0.6294
# Epoch 459, CIFAR-10 Batch 5:   cost_score 0.291714 accuracy_score 0.6266
# Epoch 460, CIFAR-10 Batch 1:   cost_score 0.314618 accuracy_score 0.6296
# Epoch 460, CIFAR-10 Batch 2:   cost_score 0.320721 accuracy_score 0.6302
# Epoch 460, CIFAR-10 Batch 3:   cost_score 0.307526 accuracy_score 0.6292
# Epoch 460, CIFAR-10 Batch 4:   cost_score 0.30165 accuracy_score 0.6292
# Epoch 460, CIFAR-10 Batch 5:   cost_score 0.303997 accuracy_score 0.623
# Epoch 461, CIFAR-10 Batch 1:   cost_score 0.323874 accuracy_score 0.6272
# Epoch 461, CIFAR-10 Batch 2:   cost_score 0.318978 accuracy_score 0.6252
# Epoch 461, CIFAR-10 Batch 3:   cost_score 0.304898 accuracy_score 0.6328
# Epoch 461, CIFAR-10 Batch 4:   cost_score 0.301111 accuracy_score 0.628
# Epoch 461, CIFAR-10 Batch 5:   cost_score 0.303458 accuracy_score 0.6238
# Epoch 462, CIFAR-10 Batch 1:   cost_score 0.305989 accuracy_score 0.6308
# Epoch 462, CIFAR-10 Batch 2:   cost_score 0.324644 accuracy_score 0.6296
# Epoch 462, CIFAR-10 Batch 3:   cost_score 0.313825 accuracy_score 0.6342
# Epoch 462, CIFAR-10 Batch 4:   cost_score 0.279199 accuracy_score 0.6374
# Epoch 462, CIFAR-10 Batch 5:   cost_score 0.306303 accuracy_score 0.6266
# Epoch 463, CIFAR-10 Batch 1:   cost_score 0.322854 accuracy_score 0.6302
# Epoch 463, CIFAR-10 Batch 2:   cost_score 0.307832 accuracy_score 0.635
# Epoch 463, CIFAR-10 Batch 3:   cost_score 0.315143 accuracy_score 0.6272
# Epoch 463, CIFAR-10 Batch 4:   cost_score 0.289753 accuracy_score 0.631
# Epoch 463, CIFAR-10 Batch 5:   cost_score 0.281541 accuracy_score 0.6268
# Epoch 464, CIFAR-10 Batch 1:   cost_score 0.333223 accuracy_score 0.6272
# Epoch 464, CIFAR-10 Batch 2:   cost_score 0.308274 accuracy_score 0.6278
# Epoch 464, CIFAR-10 Batch 3:   cost_score 0.293455 accuracy_score 0.6318
# Epoch 464, CIFAR-10 Batch 4:   cost_score 0.313813 accuracy_score 0.6254
# Epoch 464, CIFAR-10 Batch 5:   cost_score 0.285382 accuracy_score 0.6266
# Epoch 465, CIFAR-10 Batch 1:   cost_score 0.321746 accuracy_score 0.627
# Epoch 465, CIFAR-10 Batch 2:   cost_score 0.328137 accuracy_score 0.629
# Epoch 465, CIFAR-10 Batch 3:   cost_score 0.29481 accuracy_score 0.6332
# Epoch 465, CIFAR-10 Batch 4:   cost_score 0.298491 accuracy_score 0.6322
# Epoch 465, CIFAR-10 Batch 5:   cost_score 0.30452 accuracy_score 0.622
# Epoch 466, CIFAR-10 Batch 1:   cost_score 0.309974 accuracy_score 0.6312
# Epoch 466, CIFAR-10 Batch 2:   cost_score 0.320796 accuracy_score 0.6302
# Epoch 466, CIFAR-10 Batch 3:   cost_score 0.298953 accuracy_score 0.6314
# Epoch 466, CIFAR-10 Batch 4:   cost_score 0.281034 accuracy_score 0.6338
# Epoch 466, CIFAR-10 Batch 5:   cost_score 0.30182 accuracy_score 0.6218
# Epoch 467, CIFAR-10 Batch 1:   cost_score 0.314491 accuracy_score 0.6268
# Epoch 467, CIFAR-10 Batch 2:   cost_score 0.300063 accuracy_score 0.6356
# Epoch 467, CIFAR-10 Batch 3:   cost_score 0.32105 accuracy_score 0.6238
# Epoch 467, CIFAR-10 Batch 4:   cost_score 0.290811 accuracy_score 0.6324
# Epoch 467, CIFAR-10 Batch 5:   cost_score 0.274448 accuracy_score 0.6304
# Epoch 468, CIFAR-10 Batch 1:   cost_score 0.325607 accuracy_score 0.625
# Epoch 468, CIFAR-10 Batch 2:   cost_score 0.312024 accuracy_score 0.6328
# Epoch 468, CIFAR-10 Batch 3:   cost_score 0.282984 accuracy_score 0.6362
# Epoch 468, CIFAR-10 Batch 4:   cost_score 0.297751 accuracy_score 0.6284
# Epoch 468, CIFAR-10 Batch 5:   cost_score 0.28604 accuracy_score 0.6242
# Epoch 469, CIFAR-10 Batch 1:   cost_score 0.306316 accuracy_score 0.6292
# Epoch 469, CIFAR-10 Batch 2:   cost_score 0.31229 accuracy_score 0.632
# Epoch 469, CIFAR-10 Batch 3:   cost_score 0.302737 accuracy_score 0.6286
# Epoch 469, CIFAR-10 Batch 4:   cost_score 0.285201 accuracy_score 0.6306
# Epoch 469, CIFAR-10 Batch 5:   cost_score 0.294975 accuracy_score 0.6212
# Epoch 470, CIFAR-10 Batch 1:   cost_score 0.316897 accuracy_score 0.6264
# Epoch 470, CIFAR-10 Batch 2:   cost_score 0.311085 accuracy_score 0.6316
# Epoch 470, CIFAR-10 Batch 3:   cost_score 0.306551 accuracy_score 0.6292
# Epoch 470, CIFAR-10 Batch 4:   cost_score 0.294328 accuracy_score 0.632
# Epoch 470, CIFAR-10 Batch 5:   cost_score 0.270705 accuracy_score 0.627
# Epoch 471, CIFAR-10 Batch 1:   cost_score 0.319454 accuracy_score 0.621
# Epoch 471, CIFAR-10 Batch 2:   cost_score 0.333448 accuracy_score 0.6236
# Epoch 471, CIFAR-10 Batch 3:   cost_score 0.296885 accuracy_score 0.6322
# Epoch 471, CIFAR-10 Batch 4:   cost_score 0.295755 accuracy_score 0.6282
# Epoch 471, CIFAR-10 Batch 5:   cost_score 0.290207 accuracy_score 0.623
# Epoch 472, CIFAR-10 Batch 1:   cost_score 0.303394 accuracy_score 0.6276
# Epoch 472, CIFAR-10 Batch 2:   cost_score 0.322634 accuracy_score 0.6266
# Epoch 472, CIFAR-10 Batch 3:   cost_score 0.28652 accuracy_score 0.6366
# Epoch 472, CIFAR-10 Batch 4:   cost_score 0.289974 accuracy_score 0.6328
# Epoch 472, CIFAR-10 Batch 5:   cost_score 0.338723 accuracy_score 0.6148
# Epoch 473, CIFAR-10 Batch 1:   cost_score 0.313406 accuracy_score 0.6284
# Epoch 473, CIFAR-10 Batch 2:   cost_score 0.300604 accuracy_score 0.6364
# Epoch 473, CIFAR-10 Batch 3:   cost_score 0.31898 accuracy_score 0.6238
# Epoch 473, CIFAR-10 Batch 4:   cost_score 0.306503 accuracy_score 0.6288
# Epoch 473, CIFAR-10 Batch 5:   cost_score 0.267129 accuracy_score 0.6364
# Epoch 474, CIFAR-10 Batch 1:   cost_score 0.313629 accuracy_score 0.6262
# Epoch 474, CIFAR-10 Batch 2:   cost_score 0.323688 accuracy_score 0.6256
# Epoch 474, CIFAR-10 Batch 3:   cost_score 0.300511 accuracy_score 0.6278
# Epoch 474, CIFAR-10 Batch 4:   cost_score 0.305727 accuracy_score 0.6276
# Epoch 474, CIFAR-10 Batch 5:   cost_score 0.281804 accuracy_score 0.6278
# Epoch 475, CIFAR-10 Batch 1:   cost_score 0.290011 accuracy_score 0.636
# Epoch 475, CIFAR-10 Batch 2:   cost_score 0.326169 accuracy_score 0.63
# Epoch 475, CIFAR-10 Batch 3:   cost_score 0.300927 accuracy_score 0.6346
# Epoch 475, CIFAR-10 Batch 4:   cost_score 0.286544 accuracy_score 0.633
# Epoch 475, CIFAR-10 Batch 5:   cost_score 0.310943 accuracy_score 0.6226
# Epoch 476, CIFAR-10 Batch 1:   cost_score 0.309549 accuracy_score 0.632
# Epoch 476, CIFAR-10 Batch 2:   cost_score 0.296327 accuracy_score 0.639
# Epoch 476, CIFAR-10 Batch 3:   cost_score 0.298148 accuracy_score 0.6332
# Epoch 476, CIFAR-10 Batch 4:   cost_score 0.295363 accuracy_score 0.6344
# Epoch 476, CIFAR-10 Batch 5:   cost_score 0.288942 accuracy_score 0.6284
# Epoch 477, CIFAR-10 Batch 1:   cost_score 0.314369 accuracy_score 0.6298
# Epoch 477, CIFAR-10 Batch 2:   cost_score 0.314059 accuracy_score 0.632
# Epoch 477, CIFAR-10 Batch 3:   cost_score 0.299069 accuracy_score 0.6294
# Epoch 477, CIFAR-10 Batch 4:   cost_score 0.293127 accuracy_score 0.629
# Epoch 477, CIFAR-10 Batch 5:   cost_score 0.275337 accuracy_score 0.63
# Epoch 478, CIFAR-10 Batch 1:   cost_score 0.309608 accuracy_score 0.6268
# Epoch 478, CIFAR-10 Batch 2:   cost_score 0.325318 accuracy_score 0.6248
# Epoch 478, CIFAR-10 Batch 3:   cost_score 0.296783 accuracy_score 0.6282
# Epoch 478, CIFAR-10 Batch 4:   cost_score 0.288708 accuracy_score 0.6276
# Epoch 478, CIFAR-10 Batch 5:   cost_score 0.280872 accuracy_score 0.6302
# Epoch 479, CIFAR-10 Batch 1:   cost_score 0.295776 accuracy_score 0.6314
# Epoch 479, CIFAR-10 Batch 2:   cost_score 0.310788 accuracy_score 0.6296
# Epoch 479, CIFAR-10 Batch 3:   cost_score 0.305132 accuracy_score 0.6274
# Epoch 479, CIFAR-10 Batch 4:   cost_score 0.28704 accuracy_score 0.6326
# Epoch 479, CIFAR-10 Batch 5:   cost_score 0.276374 accuracy_score 0.6266
# Epoch 480, CIFAR-10 Batch 1:   cost_score 0.316649 accuracy_score 0.622
# Epoch 480, CIFAR-10 Batch 2:   cost_score 0.312551 accuracy_score 0.627
# Epoch 480, CIFAR-10 Batch 3:   cost_score 0.292829 accuracy_score 0.6292
# Epoch 480, CIFAR-10 Batch 4:   cost_score 0.273758 accuracy_score 0.6314
# Epoch 480, CIFAR-10 Batch 5:   cost_score 0.274929 accuracy_score 0.6276
# Epoch 481, CIFAR-10 Batch 1:   cost_score 0.316427 accuracy_score 0.6244
# Epoch 481, CIFAR-10 Batch 2:   cost_score 0.311411 accuracy_score 0.6326
# Epoch 481, CIFAR-10 Batch 3:   cost_score 0.285495 accuracy_score 0.6324
# Epoch 481, CIFAR-10 Batch 4:   cost_score 0.28496 accuracy_score 0.6302
# Epoch 481, CIFAR-10 Batch 5:   cost_score 0.284009 accuracy_score 0.626
# Epoch 482, CIFAR-10 Batch 1:   cost_score 0.312297 accuracy_score 0.6258
# Epoch 482, CIFAR-10 Batch 2:   cost_score 0.313781 accuracy_score 0.6322
# Epoch 482, CIFAR-10 Batch 3:   cost_score 0.306383 accuracy_score 0.6304
# Epoch 482, CIFAR-10 Batch 4:   cost_score 0.282575 accuracy_score 0.6324
# Epoch 482, CIFAR-10 Batch 5:   cost_score 0.274817 accuracy_score 0.631
# Epoch 483, CIFAR-10 Batch 1:   cost_score 0.315794 accuracy_score 0.627
# Epoch 483, CIFAR-10 Batch 2:   cost_score 0.316758 accuracy_score 0.628
# Epoch 483, CIFAR-10 Batch 3:   cost_score 0.284791 accuracy_score 0.6332
# Epoch 483, CIFAR-10 Batch 4:   cost_score 0.272943 accuracy_score 0.6322
# Epoch 483, CIFAR-10 Batch 5:   cost_score 0.295597 accuracy_score 0.622
# Epoch 484, CIFAR-10 Batch 1:   cost_score 0.310614 accuracy_score 0.6246
# Epoch 484, CIFAR-10 Batch 2:   cost_score 0.297544 accuracy_score 0.6326
# Epoch 484, CIFAR-10 Batch 3:   cost_score 0.313707 accuracy_score 0.6246
# Epoch 484, CIFAR-10 Batch 4:   cost_score 0.302286 accuracy_score 0.6298
# Epoch 484, CIFAR-10 Batch 5:   cost_score 0.267394 accuracy_score 0.6342
# Epoch 485, CIFAR-10 Batch 1:   cost_score 0.332802 accuracy_score 0.6228
# Epoch 485, CIFAR-10 Batch 2:   cost_score 0.312363 accuracy_score 0.6292
# Epoch 485, CIFAR-10 Batch 3:   cost_score 0.280719 accuracy_score 0.6348
# Epoch 485, CIFAR-10 Batch 4:   cost_score 0.294064 accuracy_score 0.627
# Epoch 485, CIFAR-10 Batch 5:   cost_score 0.293374 accuracy_score 0.6226
# Epoch 486, CIFAR-10 Batch 1:   cost_score 0.305225 accuracy_score 0.6334
# Epoch 486, CIFAR-10 Batch 2:   cost_score 0.308141 accuracy_score 0.632
# Epoch 486, CIFAR-10 Batch 3:   cost_score 0.297855 accuracy_score 0.6284
# Epoch 486, CIFAR-10 Batch 4:   cost_score 0.291936 accuracy_score 0.627
# Epoch 486, CIFAR-10 Batch 5:   cost_score 0.288361 accuracy_score 0.6214
# Epoch 487, CIFAR-10 Batch 1:   cost_score 0.316209 accuracy_score 0.625
# Epoch 487, CIFAR-10 Batch 2:   cost_score 0.311564 accuracy_score 0.6274
# Epoch 487, CIFAR-10 Batch 3:   cost_score 0.290188 accuracy_score 0.6288
# Epoch 487, CIFAR-10 Batch 4:   cost_score 0.295347 accuracy_score 0.6246
# Epoch 487, CIFAR-10 Batch 5:   cost_score 0.280252 accuracy_score 0.6264
# Epoch 488, CIFAR-10 Batch 1:   cost_score 0.294424 accuracy_score 0.6306
# Epoch 488, CIFAR-10 Batch 2:   cost_score 0.329819 accuracy_score 0.6212
# Epoch 488, CIFAR-10 Batch 3:   cost_score 0.28763 accuracy_score 0.634
# Epoch 488, CIFAR-10 Batch 4:   cost_score 0.28301 accuracy_score 0.6288
# Epoch 488, CIFAR-10 Batch 5:   cost_score 0.301336 accuracy_score 0.6216
# Epoch 489, CIFAR-10 Batch 1:   cost_score 0.294137 accuracy_score 0.6286
# Epoch 489, CIFAR-10 Batch 2:   cost_score 0.300325 accuracy_score 0.6316
# Epoch 489, CIFAR-10 Batch 3:   cost_score 0.313793 accuracy_score 0.6244
# Epoch 489, CIFAR-10 Batch 4:   cost_score 0.294725 accuracy_score 0.6292
# Epoch 489, CIFAR-10 Batch 5:   cost_score 0.27851 accuracy_score 0.6274
# Epoch 490, CIFAR-10 Batch 1:   cost_score 0.311051 accuracy_score 0.6266
# Epoch 490, CIFAR-10 Batch 2:   cost_score 0.292383 accuracy_score 0.6342
# Epoch 490, CIFAR-10 Batch 3:   cost_score 0.276715 accuracy_score 0.6334
# Epoch 490, CIFAR-10 Batch 4:   cost_score 0.296702 accuracy_score 0.6258
# Epoch 490, CIFAR-10 Batch 5:   cost_score 0.282252 accuracy_score 0.6244
# Epoch 491, CIFAR-10 Batch 1:   cost_score 0.299475 accuracy_score 0.628
# Epoch 491, CIFAR-10 Batch 2:   cost_score 0.298365 accuracy_score 0.6338
# Epoch 491, CIFAR-10 Batch 3:   cost_score 0.284535 accuracy_score 0.6336
# Epoch 491, CIFAR-10 Batch 4:   cost_score 0.268276 accuracy_score 0.6372
# Epoch 491, CIFAR-10 Batch 5:   cost_score 0.286281 accuracy_score 0.6268
# Epoch 492, CIFAR-10 Batch 1:   cost_score 0.325102 accuracy_score 0.6232
# Epoch 492, CIFAR-10 Batch 2:   cost_score 0.283951 accuracy_score 0.6362
# Epoch 492, CIFAR-10 Batch 3:   cost_score 0.292454 accuracy_score 0.6306
# Epoch 492, CIFAR-10 Batch 4:   cost_score 0.317605 accuracy_score 0.6238
# Epoch 492, CIFAR-10 Batch 5:   cost_score 0.25587 accuracy_score 0.6346
# Epoch 493, CIFAR-10 Batch 1:   cost_score 0.291468 accuracy_score 0.6328
# Epoch 493, CIFAR-10 Batch 2:   cost_score 0.321326 accuracy_score 0.6288
# Epoch 493, CIFAR-10 Batch 3:   cost_score 0.277564 accuracy_score 0.6402
# Epoch 493, CIFAR-10 Batch 4:   cost_score 0.293937 accuracy_score 0.633
# Epoch 493, CIFAR-10 Batch 5:   cost_score 0.295934 accuracy_score 0.6236
# Epoch 494, CIFAR-10 Batch 1:   cost_score 0.300892 accuracy_score 0.6266
# Epoch 494, CIFAR-10 Batch 2:   cost_score 0.31724 accuracy_score 0.6276
# Epoch 494, CIFAR-10 Batch 3:   cost_score 0.292901 accuracy_score 0.6314
# Epoch 494, CIFAR-10 Batch 4:   cost_score 0.274822 accuracy_score 0.6328
# Epoch 494, CIFAR-10 Batch 5:   cost_score 0.285782 accuracy_score 0.625
# Epoch 495, CIFAR-10 Batch 1:   cost_score 0.31387 accuracy_score 0.6282
# Epoch 495, CIFAR-10 Batch 2:   cost_score 0.303656 accuracy_score 0.631
# Epoch 495, CIFAR-10 Batch 3:   cost_score 0.29756 accuracy_score 0.629
# Epoch 495, CIFAR-10 Batch 4:   cost_score 0.296708 accuracy_score 0.6268
# Epoch 495, CIFAR-10 Batch 5:   cost_score 0.278969 accuracy_score 0.6276
# Epoch 496, CIFAR-10 Batch 1:   cost_score 0.299782 accuracy_score 0.6294
# Epoch 496, CIFAR-10 Batch 2:   cost_score 0.301638 accuracy_score 0.632
# Epoch 496, CIFAR-10 Batch 3:   cost_score 0.291479 accuracy_score 0.6272
# Epoch 496, CIFAR-10 Batch 4:   cost_score 0.278832 accuracy_score 0.6304
# Epoch 496, CIFAR-10 Batch 5:   cost_score 0.297643 accuracy_score 0.624
# Epoch 497, CIFAR-10 Batch 1:   cost_score 0.30677 accuracy_score 0.6268
# Epoch 497, CIFAR-10 Batch 2:   cost_score 0.289482 accuracy_score 0.6382
# Epoch 497, CIFAR-10 Batch 3:   cost_score 0.303595 accuracy_score 0.632
# Epoch 497, CIFAR-10 Batch 4:   cost_score 0.299098 accuracy_score 0.6292
# Epoch 497, CIFAR-10 Batch 5:   cost_score 0.260628 accuracy_score 0.6314
# Epoch 498, CIFAR-10 Batch 1:   cost_score 0.300203 accuracy_score 0.6264
# Epoch 498, CIFAR-10 Batch 2:   cost_score 0.302702 accuracy_score 0.6314
# Epoch 498, CIFAR-10 Batch 3:   cost_score 0.281765 accuracy_score 0.6352
# Epoch 498, CIFAR-10 Batch 4:   cost_score 0.286136 accuracy_score 0.6306
# Epoch 498, CIFAR-10 Batch 5:   cost_score 0.266294 accuracy_score 0.628
# Epoch 499, CIFAR-10 Batch 1:   cost_score 0.297113 accuracy_score 0.626
# Epoch 499, CIFAR-10 Batch 2:   cost_score 0.30521 accuracy_score 0.629
# Epoch 499, CIFAR-10 Batch 3:   cost_score 0.286797 accuracy_score 0.6344
# Epoch 499, CIFAR-10 Batch 4:   cost_score 0.278972 accuracy_score 0.6346
# Epoch 499, CIFAR-10 Batch 5:   cost_score 0.270822 accuracy_score 0.6264
# Epoch 500, CIFAR-10 Batch 1:   cost_score 0.293021 accuracy_score 0.6242
# Epoch 500, CIFAR-10 Batch 2:   cost_score 0.292424 accuracy_score 0.6358
# Epoch 500, CIFAR-10 Batch 3:   cost_score 0.278104 accuracy_score 0.6338
# Epoch 500, CIFAR-10 Batch 4:   cost_score 0.28753 accuracy_score 0.6302
# Epoch 500, CIFAR-10 Batch 5:   cost_score 0.284796 accuracy_score 0.6238

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.6201155781745911

# %% [markdown]
# ## Why 50-70% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 70%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
